# %% [markdown]
# # Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_predict

from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC
from sklearn.ensemble import StackingClassifier

from sklearn.linear_model import Perceptron
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.neural_network import MLPClassifier
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# Importing dataset into a dataframe

# %%
dfc = pd.read_csv(r'D:\Users\sathi\Downloads\NUSW-NB15_features.csv',encoding='cp1252')
headers = dfc.Name
df = pd.read_csv(r'D:\Users\sathi\Downloads\UNSW-NB15_1.csv', names=headers)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 dfc = pd.read_csv(r'D:\Users\sathi\Downloads\NUSW-NB15_features.csv',encoding='cp1252')
#       2 headers = dfc.Name
#       3 df = pd.read_csv(r'D:\Users\sathi\Downloads\UNSW-NB15_1.csv', names=headers)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700001 entries, 0 to 700000
# Data columns (total 49 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   srcip             700001 non-null  object
#  1   sport             700001 non-null  object
#  2   dstip             700001 non-null  object
#  3   dsport            700001 non-null  object
#  4   proto             700001 non-null  object
#  5   state             700001 non-null  object
#  6   dur               700001 non-null  float64
#  7   sbytes            700001 non-null  int64
#  8   dbytes            700001 non-null  int64
#  9   sttl              700001 non-null  int64
#  10  dttl              700001 non-null  int64
#  11  sloss             700001 non-null  int64
#  12  dloss             700001 non-null  int64
#  13  service           700001 non-null  object
#  14  Sload             700001 non-null  float64
#  15  Dload             700001 non-null  float64
#  16  Spkts             700001 non-null  int64
#  17  Dpkts             700001 non-null  int64
#  18  swin              700001 non-null  int64
#  19  dwin              700001 non-null  int64
#  20  stcpb             700001 non-null  int64
#  21  dtcpb             700001 non-null  int64
#  22  smeansz           700001 non-null  int64
#  23  dmeansz           700001 non-null  int64
#  24  trans_depth       700001 non-null  int64
#  25  res_bdy_len       700001 non-null  int64
#  26  Sjit              700001 non-null  float64
#  27  Djit              700001 non-null  float64
#  28  Stime             700001 non-null  int64
#  29  Ltime             700001 non-null  int64
#  30  Sintpkt           700001 non-null  float64
#  31  Dintpkt           700001 non-null  float64
#  32  tcprtt            700001 non-null  float64
#  33  synack            700001 non-null  float64
#  34  ackdat            700001 non-null  float64
#  35  is_sm_ips_ports   700001 non-null  int64
#  36  ct_state_ttl      700001 non-null  int64
#  37  ct_flw_http_mthd  700001 non-null  int64
#  38  is_ftp_login      700001 non-null  int64
#  39  ct_ftp_cmd        700001 non-null  int64
#  40  ct_srv_src        700001 non-null  int64
#  41  ct_srv_dst        700001 non-null  int64
#  42  ct_dst_ltm        700001 non-null  int64
#  43  ct_src_ ltm       700001 non-null  int64
#  44  ct_src_dport_ltm  700001 non-null  int64
#  45  ct_dst_sport_ltm  700001 non-null  int64
#  46  ct_dst_src_ltm    700001 non-null  int64
#  47  attack_cat        22215 non-null   object
#  48  Label             700001 non-null  int64
# dtypes: float64(10), int64(31), object(8)
# memory usage: 261.7+ MB

# %%
print('Dataset Shape: ',df.shape)
print('\nSum of Null Values:\n', df.isnull().sum())
print('\nStatistics: ')
df.describe()
# Out:
# Dataset Shape:  (700001, 49)
#
# Sum of Null Values:
#  srcip                    0
# sport                    0
# dstip                    0
# dsport                   0
# proto                    0
# state                    0
# dur                      0
# sbytes                   0
# dbytes                   0
# sttl                     0
# dttl                     0
# sloss                    0
# dloss                    0
# service                  0
# Sload                    0
# Dload                    0
# Spkts                    0
# Dpkts                    0
# swin                     0
# dwin                     0
# stcpb                    0
# dtcpb                    0
# smeansz                  0
# dmeansz                  0
# trans_depth              0
# res_bdy_len              0
# Sjit                     0
# Djit                     0
# Stime                    0
# Ltime                    0
# Sintpkt                  0
# Dintpkt                  0
# tcprtt                   0
# synack                   0
# ackdat                   0
# is_sm_ips_ports          0
# ct_state_ttl             0
# ct_flw_http_mthd         0
# is_ftp_login             0
# ct_ftp_cmd               0
# ct_srv_src               0
# ct_srv_dst               0
# ct_dst_ltm               0
# ct_src_ ltm              0
# ct_src_dport_ltm         0
# ct_dst_sport_ltm         0
# ct_dst_src_ltm           0
# attack_cat          677786
# Label                    0
# dtype: int64
#
# Statistics:
#                  dur        sbytes        dbytes           sttl  \
# count  700001.000000  7.000010e+05  7.000010e+05  700001.000000
# mean        0.863391  5.009637e+03  4.833038e+04      38.513848
# std        25.935765  4.489868e+04  1.860516e+05      39.996956
# min         0.000000  0.000000e+00  0.000000e+00       0.000000
# 25%         0.003931  4.240000e+02  3.040000e+02      31.000000
# 50%         0.027594  2.024000e+03  3.380000e+03      31.000000
# 75%         0.346518  3.806000e+03  2.243200e+04      31.000000
# max      8786.637695  1.367739e+07  1.465542e+07     255.000000
#
#                 dttl          sloss          dloss         Sload  \
# count  700001.000000  700001.000000  700001.000000  7.000010e+05
# mean       31.980783       6.330444      21.326271  6.024271e+06
# std        30.450757      18.855979      64.733376  5.181492e+07
# min         0.000000       0.000000       0.000000  0.000000e+00
# 25%        29.000000       0.000000       0.000000  7.885915e+04
# 50%        29.000000       4.000000       5.000000  5.362718e+05
# 75%        29.000000       7.000000      16.000000  1.078489e+06
# max       254.000000    5096.000000    5483.000000  5.268000e+09
#
#               Dload          Spkts  ...   is_ftp_login     ct_ftp_cmd  \
# count  7.000010e+05  700001.000000  ...  700001.000000  700001.000000
# mean   3.011023e+06      41.746643  ...       0.019623       0.031116
# std    4.499952e+06      80.198729  ...       0.138700       0.278212
# min    0.000000e+00       0.000000  ...       0.000000       0.000000
# 25%    7.640437e+04       4.000000  ...       0.000000       0.000000
# 50%    6.686759e+05      16.000000  ...       0.000000       0.000000
# 75%    3.856223e+06      52.000000  ...       0.000000       0.000000
# max    1.287619e+08   10200.000000  ...       1.000000       8.000000
#
#           ct_srv_src     ct_srv_dst     ct_dst_ltm    ct_src_ ltm  \
# count  700001.000000  700001.000000  700001.000000  700001.000000
# mean        6.380239       6.034169       4.153233       4.668593
# std         5.075147       4.635608       3.740439       4.189667
# min         1.000000       1.000000       1.000000       1.000000
# 25%         2.000000       2.000000       2.000000       2.000000
# 50%         5.000000       5.000000       3.000000       4.000000
# 75%         9.000000       8.000000       5.000000       6.000000
# max        44.000000      42.000000      42.000000      50.000000
#
#        ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm          Label
# count     700001.000000     700001.000000   700001.000000  700001.000000
# mean           1.685498          1.401911        2.188105       0.031736
# std            1.871052          1.426013        2.211199       0.175296
# min            1.000000          1.000000        1.000000       0.000000
# 25%            1.000000          1.000000        1.000000       0.000000
# 50%            1.000000          1.000000        1.000000       0.000000
# 75%            2.000000          1.000000        3.000000       0.000000
# max           36.000000         34.000000       38.000000       1.000000
#
# [8 rows x 41 columns]

# %%
print('Correlation with Attack: ')
df.corrwith(df.Label)
# Out:
# Correlation with Attack:
# dur                 0.002184
# sbytes              0.032486
# dbytes             -0.037494
# sttl                0.836553
# dttl                0.453985
# sloss              -0.002303
# dloss              -0.046677
# Sload               0.253598
# Dload              -0.120050
# Spkts              -0.054768
# Dpkts              -0.055334
# swin               -0.110972
# dwin               -0.110475
# stcpb              -0.074101
# dtcpb              -0.076247
# smeansz             0.021810
# dmeansz            -0.136598
# trans_depth        -0.022612
# res_bdy_len        -0.015595
# Sjit                0.075497
# Djit               -0.011419
# Stime              -0.227914
# Ltime              -0.227906
# Sintpkt            -0.008215
# Dintpkt             0.001983
# tcprtt              0.331373
# synack              0.296306
# ackdat              0.328984
# is_sm_ips_ports    -0.009061
# ct_state_ttl        0.742853
# ct_flw_http_mthd   -0.024534
# is_ftp_login       -0.022793
# ct_ftp_cmd         -0.018842
# ct_srv_src          0.030082
# ct_srv_dst          0.023830
# ct_dst_ltm         -0.056345
# ct_src_ ltm        -0.045965
# ct_src_dport_ltm    0.106179
# ct_dst_sport_ltm    0.110409
# ct_dst_src_ltm      0.053946
# Label               1.000000
# dtype: float64

# %% [markdown]
# Attributes with high correlation with Attack

# %%
highcorrelation = sorted(abs(df.corrwith(df.Label)), reverse=True)
print(highcorrelation)
# Out:
# [1.0, 0.8365527653576198, 0.7428530575273065, 0.45398504833370373, 0.3313733240309604, 0.3289844240629145, 0.2963055714501239, 0.2535978966603602, 0.22791410112267688, 0.2279064362012862, 0.1365977951645302, 0.1200503452736019, 0.11097157521092738, 0.11047546851201456, 0.11040897464856074, 0.10617863584280826, 0.07624715895338198, 0.07549720178298548, 0.07410086092265784, 0.05634490481728676, 0.055333816930217404, 0.054767798520025286, 0.053946370229647704, 0.0466774700651257, 0.045965269132459866, 0.03749371984970069, 0.03248554123836318, 0.030082386431715343, 0.0245339243294696, 0.0238298870879962, 0.02279274310315678, 0.022612031864635694, 0.021809536392086375, 0.018841899660986202, 0.015595280620429548, 0.011419101118732428, 0.00906078180869508, 0.008214937496263714, 0.00230266327277979, 0.002183597520566378, 0.001982860703811454]

# %% [markdown]
# Imbalance in the dataset

# %%
# Data Visualization
print('Visualization of Attack: ')
sns.countplot(x='Label', data=df)
print('Number of records with no anomalies: ', df[df['Label'] == 0].shape[0])
print('Number of records with anomalies: ', df[df['Label'] == 1].shape[0])
# Out:
# Visualization of Attack:
# Number of records with no anomalies:  677786
# Number of records with anomalies:  22215

# %% [markdown]
# Finding records with same source and destination ip

# %%
count = 0
for i in df.values:
    if i[0] == i[2]:
        count += 1
print('Records with same source and destination IP: ',count)
print('Percentage of records with same source and destination IP: ',(count/df.shape[0])*100,' %')
print('Total number of records: ',df.shape[0])
# Out:
# Records with same source and destination IP:  1858
# Percentage of records with same source and destination IP:  0.2654281922454396  %
# Total number of records:  700001

# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# Data And Target Separation

# %%
data = df.drop('Label', axis = 1) #axis = 1 - column, axis = 0 - rows
target = df.Label
print('Data Shape: ', data.shape)
print('Target Shape: ', target.shape)
# Out:
# Data Shape:  (700001, 48)
# Target Shape:  (700001,)

# %% [markdown]
# Remove unnecessary attributes

# %%
todrop = ['srcip','sport','dstip','dsport','sloss','dloss','Sintpkt','Dintpkt','Stime','Ltime','is_sm_ips_ports','attack_cat']
data.drop(todrop,axis = 1,inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700001 entries, 0 to 700000
# Data columns (total 36 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   proto             700001 non-null  object
#  1   state             700001 non-null  object
#  2   dur               700001 non-null  float64
#  3   sbytes            700001 non-null  int64
#  4   dbytes            700001 non-null  int64
#  5   sttl              700001 non-null  int64
#  6   dttl              700001 non-null  int64
#  7   service           700001 non-null  object
#  8   Sload             700001 non-null  float64
#  9   Dload             700001 non-null  float64
#  10  Spkts             700001 non-null  int64
#  11  Dpkts             700001 non-null  int64
#  12  swin              700001 non-null  int64
#  13  dwin              700001 non-null  int64
#  14  stcpb             700001 non-null  int64
#  15  dtcpb             700001 non-null  int64
#  16  smeansz           700001 non-null  int64
#  17  dmeansz           700001 non-null  int64
#  18  trans_depth       700001 non-null  int64
#  19  res_bdy_len       700001 non-null  int64
#  20  Sjit              700001 non-null  float64
#  21  Djit              700001 non-null  float64
#  22  tcprtt            700001 non-null  float64
#  23  synack            700001 non-null  float64
#  24  ackdat            700001 non-null  float64
#  25  ct_state_ttl      700001 non-null  int64
#  26  ct_flw_http_mthd  700001 non-null  int64
#  27  is_ftp_login      700001 non-null  int64
#  28  ct_ftp_cmd        700001 non-null  int64
#  29  ct_srv_src        700001 non-null  int64
#  30  ct_srv_dst        700001 non-null  int64
#  31  ct_dst_ltm        700001 non-null  int64
#  32  ct_src_ ltm       700001 non-null  int64
#  33  ct_src_dport_ltm  700001 non-null  int64
#  34  ct_dst_sport_ltm  700001 non-null  int64
#  35  ct_dst_src_ltm    700001 non-null  int64
# dtypes: float64(8), int64(25), object(3)
# memory usage: 192.3+ MB

# %% [markdown]
# 2. Label Encoding

# %%
labelencoder = LabelEncoder()

data.proto  = labelencoder.fit_transform(data.proto )
data.state = labelencoder.fit_transform(data.state)
data.service  = labelencoder.fit_transform(data.service)


data
# Out:
#         proto  state       dur  sbytes   dbytes  sttl  dttl  service  \
# 0         120      2  0.001055     132      164    31    29        2
# 1         120      2  0.036133     528      304    31    29        0
# 2         120      2  0.001119     146      178    31    29        2
# 3         120      2  0.001209     132      164    31    29        2
# 4         120      2  0.001169     146      178    31    29        2
# ...       ...    ...       ...     ...      ...   ...   ...      ...
# 699996    114      5  0.020383     320     1874    31    29        0
# 699997    114      5  1.402957   19410  1087890    31    29        5
# 699998    114      5  0.007108    2158     2464    31    29        0
# 699999    120      2  0.004435     568      304    31    29        0
# 700000    114      5  0.072974    4238    60788    31    29        0
#
#                Sload         Dload  ...  ct_flw_http_mthd  is_ftp_login  \
# 0       5.004739e+05  6.218009e+05  ...                 0             0
# 1       8.767609e+04  5.048017e+04  ...                 0             0
# 2       5.218945e+05  6.362824e+05  ...                 0             0
# 3       4.367246e+05  5.425972e+05  ...                 0             0
# 4       4.995722e+05  6.090676e+05  ...                 0             0
# ...              ...           ...  ...               ...           ...
# 699996  1.047932e+05  6.436736e+05  ...                 0             0
# 699997  1.103783e+05  6.195098e+06  ...                 4             0
# 699998  2.328644e+06  2.658413e+06  ...                 0             0
# 699999  7.684329e+05  4.112740e+05  ...                 0             0
# 700000  4.582454e+05  6.571546e+06  ...                 0             0
#
#         ct_ftp_cmd  ct_srv_src  ct_srv_dst  ct_dst_ltm  ct_src_ ltm  \
# 0                0           3           7           1            3
# 1                0           2           4           2            3
# 2                0          12           8           1            2
# 3                0           6           9           1            1
# 4                0           7           9           1            1
# ...            ...         ...         ...         ...          ...
# 699996           0           8          20           7            5
# 699997           0           1           1           2            7
# 699998           0          13          13           6            7
# 699999           0          10          13           6            5
# 700000           0          13          13           6            7
#
#         ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm
# 0                      1                 1               1
# 1                      1                 1               2
# 2                      2                 1               1
# 3                      1                 1               1
# 4                      1                 1               1
# ...                  ...               ...             ...
# 699996                 1                 1               4
# 699997                 2                 2               2
# 699998                 2                 1               2
# 699999                 1                 1               3
# 700000                 1                 1               2
#
# [700001 rows x 36 columns]

# %% [markdown]
# Handling data imbalance using smote

# %%
sampler = SMOTE(random_state = 42)
data, target = sampler.fit_resample(data,target.values.ravel())

# %%
target1 = pd.DataFrame({'Attack':target})
sns.countplot(data = target1)
plt.show()

# %% [markdown]
# Train Test Split of dataset

# %%
X_train, X_test, Y_train, Y_test = train_test_split(data,target,test_size=0.2,random_state=10)
X_train
# Out:
#         proto  state       dur  sbytes   dbytes  sttl  dttl  service  \
# 298810    120      2  0.001042     146      178    31    29        2
# 51582     120      2  0.001040     130      162    31    29        2
# 552717    114      5  1.810871    7816    15130    31    29        0
# 423102    114      5  0.016677    2958    32586    31    29        0
# 579114    114      5  0.004710    3848     2456    31    29        0
# ...       ...    ...       ...     ...      ...   ...   ...      ...
# 533660    120      2  0.001024     146      178    31    29        2
# 105595    114      5  8.978476   19722  1087890    31    29        5
# 617841    120      2  0.366325     568      312    31    29        0
# 443712    120      2  0.010297     536      304    31    29        0
# 345353    120      2  0.001029     146      178    31    29        2
#
#                Sload         Dload  ...  ct_flw_http_mthd  is_ftp_login  \
# 298810  5.604606e+05  6.833013e+05  ...                 0             0
# 51582   5.000000e+05  6.230769e+05  ...                 0             0
# 552717  3.424650e+04  6.631063e+04  ...                 0             0
# 423102  1.389698e+06  1.531930e+07  ...                 0             0
# 579114  6.174098e+06  3.940552e+06  ...                 0             0
# ...              ...           ...  ...               ...           ...
# 533660  5.703125e+05  6.953125e+05  ...                 0             0
# 105595  1.752547e+04  9.680325e+05  ...                 0             0
# 617841  9.303215e+03  5.110216e+03  ...                 0             0
# 443712  3.123240e+05  1.771390e+05  ...                 0             0
# 345353  5.675413e+05  6.919339e+05  ...                 0             0
#
#         ct_ftp_cmd  ct_srv_src  ct_srv_dst  ct_dst_ltm  ct_src_ ltm  \
# 298810           0           6           2           3            7
# 51582            0           2           2           2            3
# 552717           0           4           8           5            9
# 423102           0          11           7           7           24
# 579114           0           6          10           4            4
# ...            ...         ...         ...         ...          ...
# 533660           0           3           1           2            2
# 105595           0           5           2           4            5
# 617841           0          10          15           4            4
# 443712           0          13          14          12           13
# 345353           0           4           5           1            4
#
#         ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm
# 298810                 4                 1               1
# 51582                  1                 1               1
# 552717                 1                 1               2
# 423102                 4                 4               7
# 579114                 1                 1               3
# ...                  ...               ...             ...
# 533660                 2                 1               1
# 105595                 3                 1               2
# 617841                 1                 1               3
# 443712                 2                 2               7
# 345353                 1                 1               1
#
# [560000 rows x 36 columns]

# %% [markdown]
# # **ML Training Models**

# %%
# !pip install lazypredict
# Out:
# Defaulting to user installation because normal site-packages is not writeable
#   WARNING: The script lazypredict.exe is installed in 'C:\Users\sathi\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting lazypredict
#   Using cached lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (8.0.4)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (1.0.2)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (4.64.0)
# Requirement already satisfied: joblib in c:\users\sathi\appdata\roaming\python\python39\site-packages (from lazypredict) (1.3.1)
# Collecting lightgbm (from lazypredict)
#   Using cached lightgbm-4.1.0-py3-none-win_amd64.whl (1.3 MB)
# Collecting xgboost (from lazypredict)
#   Using cached xgboost-2.0.2-py3-none-win_amd64.whl (99.8 MB)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->lazypredict) (0.4.4)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from lightgbm->lazypredict) (1.21.5)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from lightgbm->lazypredict) (1.7.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->lazypredict) (2021.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->lazypredict) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->lazypredict) (1.16.0)
# Installing collected packages: xgboost, lightgbm, lazypredict
# Successfully installed lazypredict-0.2.12 lightgbm-4.1.0 xgboost-2.0.2

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_test, Y_train, Y_test)
models,predictions = clf.fit(X_train, X_test, Y_train, Y_test)
print(models)
# Out:
#  97%|█████████▋| 28/29 [46:11<01:49, 109.43s/it]
# [LightGBM] [Info] Number of positive: 17845, number of negative: 542155
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.049138 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4632
# [LightGBM] [Info] Number of data points in the train set: 560000, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.031866 -> initscore=-3.413829
# [LightGBM] [Info] Start training from score -3.413829
# 100%|██████████| 29/29 [46:16<00:00, 95.75s/it]
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
#  97%|█████████▋| 28/29 [44:21<01:56, 116.74s/it]
# [LightGBM] [Info] Number of positive: 17845, number of negative: 542155
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.058353 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4632
# [LightGBM] [Info] Number of data points in the train set: 560000, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.031866 -> initscore=-3.413829
# [LightGBM] [Info] Start training from score -3.413829
# 100%|██████████| 29/29 [44:26<00:00, 91.95s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.99               0.99     0.99      0.99
# QuadraticDiscriminantAnalysis      0.98               0.99     0.99      0.99
# BernoulliNB                        0.99               0.99     0.99      0.99
# GaussianNB                         0.98               0.99     0.99      0.98
# RandomForestClassifier             1.00               0.99     0.99      1.00
# LinearDiscriminantAnalysis         0.99               0.99     0.99      0.99
# SVC                                1.00               0.98     0.98      1.00
# LGBMClassifier                     1.00               0.98     0.98      1.00
# ExtraTreesClassifier               1.00               0.98     0.98      1.00
# XGBClassifier                      1.00               0.98     0.98      1.00
# BaggingClassifier                  1.00               0.98     0.98      1.00
# LinearSVC                          0.99               0.97     0.97      0.99
# LogisticRegression                 0.99               0.97     0.97      0.99
# Perceptron                         0.99               0.97     0.97      0.99
# DecisionTreeClassifier             1.00               0.97     0.97      1.00
# AdaBoostClassifier                 1.00               0.97     0.97      1.00
# ExtraTreeClassifier                1.00               0.97     0.97      1.00
# KNeighborsClassifier               1.00               0.97     0.97      1.00
# CalibratedClassifierCV             0.99               0.96     0.96      0.99
# RidgeClassifier                    0.99               0.96     0.96      0.99
# RidgeClassifierCV                  0.99               0.96     0.96      0.99
# SGDClassifier                      0.99               0.94     0.94      0.99
# PassiveAggressiveClassifier        0.99               0.89     0.89      0.99
# DummyClassifier                    0.97               0.50     0.50      0.95
#
#                                Time Taken
# Model
# NearestCentroid                      1.09
# QuadraticDiscriminantAnalysis        2.22
# BernoulliNB                          1.34
# GaussianNB                           1.30
# RandomForestClassifier              43.72
# LinearDiscriminantAnalysis           3.47
# SVC                                685.90
# LGBMClassifier                       5.10
# ExtraTreesClassifier                18.29
# XGBClassifier                        8.92
# BaggingClassifier                   15.15
# LinearSVC                           70.21
# LogisticRegression                   5.61
# Perceptron                           2.67
# DecisionTreeClassifier               2.95
# AdaBoostClassifier                  55.96
# ExtraTreeClassifier                  1.09
# KNeighborsClassifier              1454.06
# CalibratedClassifierCV             273.31
# RidgeClassifier                      1.38
# RidgeClassifierCV                    2.79
# SGDClassifier                        2.87
# PassiveAggressiveClassifier          1.98
# DummyClassifier                      0.93

# %% [markdown]
# **K-fold Cross Validation**

# %%
#Choosing k value for cross validation using Decision Tree
kcrossval = []
kcrossvalAcc = []
for i in range(1,10):
  y = target
  train = cross_validate(estimator=DecisionTreeClassifier(),X=data,y=y,n_jobs=-1,cv=i+1,return_train_score = True)
  test = cross_val_predict(estimator=DecisionTreeClassifier(),X=data,y=y,n_jobs=-1,cv=i+1)
  kcrossvalAcc.append(f1_score(y,test))
  kcrossval.append(i+1)
plt.scatter(x=kcrossval, y=kcrossvalAcc)
bestkcv = kcrossvalAcc.index(max(kcrossvalAcc)) + 1
print('Best K value: ',bestkcv)

# %%
y=target
bestkcv = 10
def cross_val(model,x,cv = bestkcv):
    print('----------------- After cross validation -----------------')
    global y
    cv_res = cross_validate(estimator=model,X=x,y=y,n_jobs=-1,cv=cv,scoring = 'accuracy',return_train_score = True)
    y_pred = cross_val_predict(estimator=model,X=x,y=y,n_jobs=-1,cv=cv)
    print('Training Score:',cv_res['train_score'].mean())
    print('Testing Score:',accuracy_score(y,y_pred))
    plt.figure(figsize=(5,5))
    sns.heatmap(confusion_matrix(y,y_pred),annot=True,cmap='GnBu',fmt = 'd')
    plt.title('The Confusion Matrix',color='black')
    plt.xlabel('Predicted',color='black')
    plt.ylabel('Actual',color='black')
    plt.show()
    print(classification_report(y,y_pred))

# %% [markdown]
# 1. K-Nearest Neighbours

# %%
knnres = []
acc = []
for i in range(20):
  KNN = KNeighborsClassifier(n_neighbors = i+1)

  KNN.fit(X_train, Y_train)
  knn_ytrain_pred = KNN.predict(X_train)
  knn_ytest_pred = KNN.predict(X_test)
  knnres.append(i+1)
  acc.append(f1_score(Y_test, knn_ytest_pred)*100)

plt.scatter(x=knnres, y=acc)
bestk = acc.index(max(acc)) + 1
print('Best K value: ',acc.index(max(acc)) + 1)

# %%
bestk = 5
KNN = KNeighborsClassifier(n_neighbors = bestk)

KNN.fit(X_train, Y_train)
knn_ytrain_pred = KNN.predict(X_train)
knn_ytest_pred = KNN.predict(X_test)
knn_ytest_pred = KNN.predict(X_test)

print('Training Score:',accuracy_score(Y_train,knn_ytrain_pred))
print('Testing Score:',accuracy_score(Y_test,knn_ytest_pred))

cross_val(KNeighborsClassifier(n_neighbors = bestk),data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\GitHubStuff\Graph-Anomaly-Detection\Project ML Analysis.ipynb Cell 28 line <cell line: 5>()
#       <a href='vscode-notebook-cell:/d%3A/GitHubStuff/Graph-Anomaly-Detection/Project%20ML%20Analysis.ipynb#X36sZmlsZQ%3D%3D?line=1'>2</a> KNN = KNeighborsClassifier(n_neighbors = bestk)
#       <a href='vscode-notebook-cell:/d%3A/GitHubStuff/Graph-Anomaly-Detection/Project%20ML%20Analysis.ipynb#X36sZmlsZQ%3D%3D?line=3'>4</a> KNN.fit(X_train, Y_train)
# ----> <a href='vscode-notebook-cell:/d%3A/GitHubStuff/Graph-Anomaly-Detection/Project%20ML%20Analysis.ipynb#X36sZmlsZQ%3D%3D?line=4'>5</a> knn_ytrain_pred = KNN.predict(X_train)
#       <a href='vscode-notebook-cell:/d%3A/GitHubStuff/Graph-Anomaly-Detection/Project%20ML%20Analysis.ipynb#X36sZmlsZQ%3D%3D?line=5'>6</a> knn_ytest_pred = KNN.predict(X_test)
#       <a href='vscode-notebook-cell:/d%3A/GitHubStuff/Graph-Anomaly-Detection/Project%20ML%20Analysis.ipynb#X36sZmlsZQ%3D%3D?line=7'>8</a> print('Training Score:',accuracy_score(Y_train,knn_ytrain_pred))
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:214, in KNeighborsClassifier.predict(self, X)
#     200 def predict(self, X):
#     201     """Predict the class labels for the provided data.
#     202
#     203     Parameters
#    (...)
#     212         Class labels for each data sample.
#     213     """
# --> 214     neigh_dist, neigh_ind = self.kneighbors(X)
#     215     classes_ = self.classes_
#     216     _y = self._y
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_base.py:752, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     749     else:
#     750         kwds = self.effective_metric_params_
# --> 752     chunked_results = list(
#     753         pairwise_distances_chunked(
#     754             X,
#     755             self._fit_X,
#     756             reduce_func=reduce_func,
#     757             metric=self.effective_metric_,
#     758             n_jobs=n_jobs,
#     759             **kwds,
#     760         )
#     761     )
#     763 elif self._fit_method in ["ball_tree", "kd_tree"]:
#     764     if issparse(X):
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1717, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1715 else:
#    1716     X_chunk = X[sl]
# -> 1717 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    1718 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    1719     metric, None
#    1720 ) is euclidean_distances:
#    1721     # zeroing diagonal, taking care of aliases of "euclidean",
#    1722     # i.e. "l2"
#    1723     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1889, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    1886         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    1887     func = partial(distance.cdist, metric=metric, **kwds)
# -> 1889 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1430, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1427 X, Y, dtype = _return_float_dtype(X, Y)
#    1429 if effective_n_jobs(n_jobs) == 1:
# -> 1430     return func(X, Y, **kwds)
#    1432 # enforce a threading backend to prevent data communication overhead
#    1433 fd = delayed(_dist_wrapper)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:330, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     324     if Y_norm_squared.shape != (1, Y.shape[0]):
#     325         raise ValueError(
#     326             f"Incompatible dimensions for Y of shape {Y.shape} and "
#     327             f"Y_norm_squared of shape {original_shape}."
#     328         )
# --> 330 return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:371, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     368     distances = _euclidean_distances_upcast(X, XX, Y, YY)
#     369 else:
#     370     # if dtype is already float64, no need to chunk and upcast
# --> 371     distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     372     distances += XX
#     373     distances += YY
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\extmath.py:153, in safe_sparse_dot(a, b, dense_output)
#     151         ret = np.dot(a, b)
#     152 else:
# --> 153     ret = a @ b
#     155 if (
#     156     sparse.issparse(a)
#     157     and sparse.issparse(b)
#     158     and dense_output
#     159     and hasattr(ret, "toarray")
#     160 ):
#     161     return ret.toarray()
#
# KeyboardInterrupt:

# %% [markdown]
# 2. Logistic Regression

# %% [markdown]
# Without imbalance handling

# %%
log_reg = LogisticRegression()
log_reg.fit(X_train,Y_train)

lr_ytrain_pred = log_reg.predict(X_train)
lr_ytest_pred = log_reg.predict(X_test)

print('Training Score:',accuracy_score(Y_train,lr_ytrain_pred))
print('Testing Score:',accuracy_score(Y_test,lr_ytest_pred))

cross_val(LogisticRegression(),data)
# Out:
# Training Score: 0.963
# Testing Score: 0.9636645452532482
# ----------------- After cross validation -----------------
# Training Score: 0.9650078274919845
# Testing Score: 0.9552357782346025
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98    677786
#            1       0.15      0.09      0.11     22215
#
#     accuracy                           0.96    700001
#    macro avg       0.56      0.53      0.54    700001
# weighted avg       0.94      0.96      0.95    700001

# %% [markdown]
# With Imbalance Handling

# %%
log_reg = LogisticRegression()
log_reg.fit(X_train,Y_train)

lr_ytrain_pred = log_reg.predict(X_train)
lr_ytest_pred = log_reg.predict(X_test)

print('Training Score:',accuracy_score(Y_train,lr_ytrain_pred))
print('Testing Score:',accuracy_score(Y_test,lr_ytest_pred))

cross_val(LogisticRegression(),data)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training Score: 0.8617769077058841
# Testing Score: 0.8628183612120318
# ----------------- After cross validation -----------------
# Training Score: 0.8619454456265958
# Testing Score: 0.8620582307690038
#               precision    recall  f1-score   support
#
#            0       0.93      0.78      0.85    677786
#            1       0.81      0.94      0.87    677786
#
#     accuracy                           0.86   1355572
#    macro avg       0.87      0.86      0.86   1355572
# weighted avg       0.87      0.86      0.86   1355572

# %% [markdown]
# 3. Random Forest

# %%
rfres = []
rfacc = []
for i in range(100):
  rfc = RandomForestClassifier(n_estimators = i+1)

  rfc.fit(X_train, Y_train)
  rfc_ytrain_pred = rfc.predict(X_train)
  rfc_ytest_pred = rfc.predict(X_test)
  rfres.append(i+1)
  rfacc.append(f1_score(Y_test, rfc_ytest_pred)*100)

plt.scatter(x=rfres, y=rfacc)
bestn = rfacc.index(max(rfacc)) + 1
print('Best n value: ',rfacc.index(max(rfacc)) + 1)

# %%
rf = RandomForestClassifier(max_depth=5,n_estimators = 61, random_state=0)
rf.fit(X_train,Y_train)

rf_ytrain_pred = rf.predict(X_train)
rf_ytest_pred = rf.predict(X_test)

print('Training Score:',accuracy_score(Y_train,rf_ytrain_pred))
print('Testing Score:',accuracy_score(Y_test,rf_ytest_pred))

cross_val(RandomForestClassifier(max_depth=2, random_state=0),data)

# %% [markdown]
# 4. Decision Tree

# %%
from sklearn.tree import plot_tree
DecisionTree = DecisionTreeClassifier()
DecisionTree.fit(X_train,Y_train) #fitting the preprocessed data with the decision tree algorithm

dt_ytrain_pred = DecisionTree.predict(X_train)
dt_ytest_pred = DecisionTree.predict(X_test)

print('Training Score:',accuracy_score(Y_train,dt_ytrain_pred))
print('Testing Score:',accuracy_score(Y_test,dt_ytest_pred))

cross_val(DecisionTreeClassifier(),data)
# Out:
# Training Score: 0.9999392857142857
# Testing Score: 0.9967643088263656
# ----------------- After cross validation -----------------
# Training Score: 0.9999056568867098
# Testing Score: 0.996706187498709
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    677786
#            1       1.00      1.00      1.00    677786
#
#     accuracy                           1.00   1355572
#    macro avg       1.00      1.00      1.00   1355572
# weighted avg       1.00      1.00      1.00   1355572

# %%
plot_tree(DecisionTree,filled=True,rounded=True,feature_names=data.columns,class_names=['0','1'])
# Out:
# [Text(0.6301409590281297, 0.9871794871794872, 'sttl <= 61.0\ngini = 0.062\nsamples = 560000\nvalue = [542155, 17845]\nclass = 0'),
#  Text(0.41887500913459685, 0.9615384615384616, 'ct_state_ttl <= 1.0\ngini = 0.0\nsamples = 537846\nvalue = [537817, 29]\nclass = 0'),
#  Text(0.4179198992969655, 0.9358974358974359, 'gini = 0.0\nsamples = 536419\nvalue = [536419, 0]\nclass = 0'),
#  Text(0.41983011897222816, 0.9358974358974359, 'proto <= 39.0\ngini = 0.04\nsamples = 1427\nvalue = [1398, 29]\nclass = 0'),
#  Text(0.41887500913459685, 0.9102564102564102, 'gini = 0.0\nsamples = 1398\nvalue = [1398, 0]\nclass = 0'),
#  Text(0.42078522880985947, 0.9102564102564102, 'gini = 0.0\nsamples = 29\nvalue = [0, 29]\nclass = 1'),
#  Text(0.8414069089216626, 0.9615384615384616, 'ct_state_ttl <= 2.5\ngini = 0.315\nsamples = 22154\nvalue = [4338, 17816]\nclass = 1'),
#  Text(0.6930812485978619, 0.9358974358974359, 'service <= 0.5\ngini = 0.264\nsamples = 20885\nvalue = [3272, 17613]\nclass = 1'),
#  Text(0.42269544848512214, 0.9102564102564102, 'synack <= 0.06\ngini = 0.384\nsamples = 12444\nvalue = [3226, 9218]\nclass = 1'),
#  Text(0.1573306705799121, 0.8846153846153846, 'sbytes <= 129.0\ngini = 0.275\nsamples = 7991\nvalue = [1317, 6674]\nclass = 1'),
#  Text(0.07870515460840496, 0.8589743589743589, 'ct_srv_src <= 5.5\ngini = 0.494\nsamples = 795\nvalue = [441, 354]\nclass = 0'),
#  Text(0.017057664756446992, 0.8333333333333334, 'proto <= 70.5\ngini = 0.464\nsamples = 285\nvalue = [104, 181]\nclass = 1'),
#  Text(0.016102554918815664, 0.8076923076923077, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]\nclass = 0'),
#  Text(0.01801277459407832, 0.8076923076923077, 'smeansz <= 51.5\ngini = 0.44\nsamples = 269\nvalue = [88, 181]\nclass = 1'),
#  Text(0.016102554918815664, 0.782051282051282, 'ct_state_ttl <= 0.5\ngini = 0.133\nsamples = 28\nvalue = [2, 26]\nclass = 1'),
#  Text(0.015147445081184336, 0.7564102564102564, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.017057664756446992, 0.7564102564102564, 'gini = 0.0\nsamples = 26\nvalue = [0, 26]\nclass = 1'),
#  Text(0.019922994269340973, 0.782051282051282, 'Sload <= 26376810.0\ngini = 0.459\nsamples = 241\nvalue = [86, 155]\nclass = 1'),
#  Text(0.018967884431709648, 0.7564102564102564, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.0208781041069723, 0.7564102564102564, 'proto <= 109.0\ngini = 0.454\nsamples = 238\nvalue = [83, 155]\nclass = 1'),
#  Text(0.019922994269340973, 0.7307692307692307, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = 1'),
#  Text(0.02183321394460363, 0.7307692307692307, 'ct_srv_dst <= 2.5\ngini = 0.462\nsamples = 229\nvalue = [83, 146]\nclass = 1'),
#  Text(0.0064469914040114614, 0.7051282051282052, 'smeansz <= 54.0\ngini = 0.5\nsamples = 41\nvalue = [21, 20]\nclass = 0'),
#  Text(0.0054918815663801334, 0.6794871794871795, 'ct_dst_ltm <= 2.5\ngini = 0.48\nsamples = 35\nvalue = [21, 14]\nclass = 0'),
#  Text(0.004536771728748806, 0.6538461538461539, 'dur <= 0.0\ngini = 0.451\nsamples = 32\nvalue = [21, 11]\nclass = 0'),
#  Text(0.0019102196752626551, 0.6282051282051282, 'ct_srv_dst <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.0009551098376313276, 0.6025641025641025, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.0028653295128939827, 0.6025641025641025, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.0071633237822349575, 0.6282051282051282, 'dur <= 0.0\ngini = 0.428\nsamples = 29\nvalue = [20, 9]\nclass = 0'),
#  Text(0.004775549188156638, 0.6025641025641025, 'ct_dst_ltm <= 1.5\ngini = 0.305\nsamples = 16\nvalue = [13, 3]\nclass = 0'),
#  Text(0.0028653295128939827, 0.5769230769230769, 'dur <= 0.0\ngini = 0.245\nsamples = 14\nvalue = [12, 2]\nclass = 0'),
#  Text(0.0019102196752626551, 0.5512820512820513, 'dur <= 0.0\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = 0'),
#  Text(0.0009551098376313276, 0.5256410256410257, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.0028653295128939827, 0.5256410256410257, 'ct_src_ ltm <= 1.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = 0'),
#  Text(0.0019102196752626551, 0.5, 'ct_srv_dst <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(0.0009551098376313276, 0.47435897435897434, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.0028653295128939827, 0.47435897435897434, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.0038204393505253103, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.0038204393505253103, 0.5512820512820513, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.0066857688634192934, 0.5769230769230769, 'ct_src_ ltm <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.0057306590257879654, 0.5512820512820513, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.007640878701050621, 0.5512820512820513, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.009551098376313277, 0.6025641025641025, 'dur <= 0.0\ngini = 0.497\nsamples = 13\nvalue = [7, 6]\nclass = 0'),
#  Text(0.008595988538681949, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.010506208213944603, 0.5769230769230769, 'ct_src_ ltm <= 1.5\ngini = 0.486\nsamples = 12\nvalue = [7, 5]\nclass = 0'),
#  Text(0.009551098376313277, 0.5512820512820513, 'ct_srv_src <= 1.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = 0'),
#  Text(0.0066857688634192934, 0.5256410256410257, 'dur <= 0.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(0.0057306590257879654, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.007640878701050621, 0.5, 'ct_srv_dst <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.0066857688634192934, 0.47435897435897434, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.008595988538681949, 0.47435897435897434, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.012416427889207259, 0.5256410256410257, 'ct_dst_ltm <= 1.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = 1'),
#  Text(0.011461318051575931, 0.5, 'dur <= 0.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = 1'),
#  Text(0.010506208213944603, 0.47435897435897434, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.012416427889207259, 0.47435897435897434, 'ct_srv_src <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.011461318051575931, 0.44871794871794873, 'ct_srv_dst <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.010506208213944603, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.012416427889207259, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.013371537726838587, 0.44871794871794873, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.013371537726838587, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.011461318051575931, 0.5512820512820513, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.0064469914040114614, 0.6538461538461539, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.007402101241642789, 0.6794871794871795, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = 1'),
#  Text(0.037219436485195795, 0.7051282051282052, 'ct_srv_dst <= 3.5\ngini = 0.442\nsamples = 188\nvalue = [62, 126]\nclass = 1'),
#  Text(0.02268385864374403, 0.6794871794871795, 'ct_srv_src <= 2.5\ngini = 0.274\nsamples = 55\nvalue = [9, 46]\nclass = 1'),
#  Text(0.018147086914995225, 0.6538461538461539, 'ct_dst_ltm <= 1.5\ngini = 0.486\nsamples = 12\nvalue = [5, 7]\nclass = 1'),
#  Text(0.01623686723973257, 0.6282051282051282, 'smeansz <= 54.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = 0'),
#  Text(0.015281757402101241, 0.6025641025641025, 'dur <= 0.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = 0'),
#  Text(0.014326647564469915, 0.5769230769230769, 'Sload <= 312000000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.013371537726838587, 0.5512820512820513, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.015281757402101241, 0.5512820512820513, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.01623686723973257, 0.5769230769230769, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.017191977077363897, 0.6025641025641025, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.02005730659025788, 0.6282051282051282, 'ct_dst_ltm <= 3.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = 1'),
#  Text(0.019102196752626553, 0.6025641025641025, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1'),
#  Text(0.021012416427889206, 0.6025641025641025, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.027220630372492838, 0.6538461538461539, 'Sload <= 121333328.0\ngini = 0.169\nsamples = 43\nvalue = [4, 39]\nclass = 1'),
#  Text(0.02387774594078319, 0.6282051282051282, 'Sload <= 46800000.0\ngini = 0.077\nsamples = 25\nvalue = [1, 24]\nclass = 1'),
#  Text(0.022922636103151862, 0.6025641025641025, 'Sload <= 39709090.0\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = 1'),
#  Text(0.021967526265520534, 0.5769230769230769, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1'),
#  Text(0.02387774594078319, 0.5769230769230769, 'ct_dst_ltm <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = 1'),
#  Text(0.022922636103151862, 0.5512820512820513, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.024832855778414518, 0.5512820512820513, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.024832855778414518, 0.6025641025641025, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]\nclass = 1'),
#  Text(0.030563514804202482, 0.6282051282051282, 'ct_dst_ltm <= 1.5\ngini = 0.278\nsamples = 18\nvalue = [3, 15]\nclass = 1'),
#  Text(0.029608404966571154, 0.6025641025641025, 'ct_src_ ltm <= 2.5\ngini = 0.337\nsamples = 14\nvalue = [3, 11]\nclass = 1'),
#  Text(0.027698185291308502, 0.5769230769230769, 'dur <= 0.0\ngini = 0.278\nsamples = 12\nvalue = [2, 10]\nclass = 1'),
#  Text(0.026743075453677174, 0.5512820512820513, 'ct_src_ ltm <= 1.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = 1'),
#  Text(0.025787965616045846, 0.5256410256410257, 'Sload <= 312000000.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = 1'),
#  Text(0.024832855778414518, 0.5, 'gini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = 1'),
#  Text(0.026743075453677174, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.027698185291308502, 0.5256410256410257, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.02865329512893983, 0.5512820512820513, 'gini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = 1'),
#  Text(0.03151862464183381, 0.5769230769230769, 'ct_src_ ltm <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.030563514804202482, 0.5512820512820513, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.03247373447946514, 0.5512820512820513, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.03151862464183381, 0.6025641025641025, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(0.051755014326647565, 0.6794871794871795, 'ct_srv_dst <= 4.5\ngini = 0.479\nsamples = 133\nvalue = [53, 80]\nclass = 1'),
#  Text(0.039040114613180514, 0.6538461538461539, 'ct_srv_src <= 2.5\ngini = 0.492\nsamples = 55\nvalue = [31, 24]\nclass = 0'),
#  Text(0.03533906399235912, 0.6282051282051282, 'Sload <= 50514286.0\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = 1'),
#  Text(0.034383954154727794, 0.6025641025641025, 'ct_srv_src <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = 0'),
#  Text(0.033428844317096466, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.03533906399235912, 0.5769230769230769, 'dur <= 0.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.034383954154727794, 0.5512820512820513, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.03629417382999045, 0.5512820512820513, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.03629417382999045, 0.6025641025641025, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(0.04274116523400191, 0.6282051282051282, 'Sload <= 46800000.0\ngini = 0.473\nsamples = 47\nvalue = [29, 18]\nclass = 0'),
#  Text(0.038204393505253106, 0.6025641025641025, 'ct_src_ ltm <= 1.5\ngini = 0.48\nsamples = 10\nvalue = [4, 6]\nclass = 1'),
#  Text(0.03724928366762178, 0.5769230769230769, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1'),
#  Text(0.039159503342884434, 0.5769230769230769, 'ct_dst_ltm <= 3.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = 0'),
#  Text(0.038204393505253106, 0.5512820512820513, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.04011461318051576, 0.5512820512820513, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.04727793696275072, 0.6025641025641025, 'ct_src_ ltm <= 1.5\ngini = 0.438\nsamples = 37\nvalue = [25, 12]\nclass = 0'),
#  Text(0.04297994269340974, 0.5769230769230769, 'ct_dst_ltm <= 1.5\ngini = 0.363\nsamples = 21\nvalue = [16, 5]\nclass = 0'),
#  Text(0.04202483285577841, 0.5512820512820513, 'Sload <= 312000000.0\ngini = 0.43\nsamples = 16\nvalue = [11, 5]\nclass = 0'),
#  Text(0.041069723018147083, 0.5256410256410257, 'dur <= 0.0\ngini = 0.391\nsamples = 15\nvalue = [11, 4]\nclass = 0'),
#  Text(0.038204393505253106, 0.5, 'Sload <= 121333328.0\ngini = 0.32\nsamples = 10\nvalue = [8, 2]\nclass = 0'),
#  Text(0.03724928366762178, 0.47435897435897434, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.039159503342884434, 0.47435897435897434, 'Sload <= 173333328.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = 0'),
#  Text(0.038204393505253106, 0.44871794871794873, 'ct_srv_src <= 4.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = 0'),
#  Text(0.03724928366762178, 0.4230769230769231, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.039159503342884434, 0.4230769230769231, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(0.04011461318051576, 0.44871794871794873, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.04393505253104107, 0.5, 'Sload <= 64380950.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = 0'),
#  Text(0.04297994269340974, 0.47435897435897434, 'Sload <= 55714286.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(0.04202483285577841, 0.44871794871794873, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.04393505253104107, 0.44871794871794873, 'ct_srv_src <= 4.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.04297994269340974, 0.4230769230769231, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.044890162368672396, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.044890162368672396, 0.47435897435897434, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.04297994269340974, 0.5256410256410257, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.04393505253104107, 0.5512820512820513, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.05157593123209169, 0.5769230769230769, 'ct_dst_ltm <= 1.5\ngini = 0.492\nsamples = 16\nvalue = [9, 7]\nclass = 0'),
#  Text(0.050620821394460364, 0.5512820512820513, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.05253104106972302, 0.5512820512820513, 'dur <= 0.0\ngini = 0.459\nsamples = 14\nvalue = [9, 5]\nclass = 0'),
#  Text(0.05157593123209169, 0.5256410256410257, 'dur <= 0.0\ngini = 0.486\nsamples = 12\nvalue = [7, 5]\nclass = 0'),
#  Text(0.050620821394460364, 0.5, 'ct_srv_src <= 3.5\ngini = 0.463\nsamples = 11\nvalue = [7, 4]\nclass = 0'),
#  Text(0.04871060171919771, 0.47435897435897434, 'ct_dst_sport_ltm <= 1.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = 1'),
#  Text(0.04775549188156638, 0.44871794871794873, 'dur <= 0.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.04680038204393505, 0.4230769230769231, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.04871060171919771, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.049665711556829036, 0.44871794871794873, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.05253104106972302, 0.47435897435897434, 'ct_srv_src <= 4.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = 0'),
#  Text(0.05157593123209169, 0.44871794871794873, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.05348615090735435, 0.44871794871794873, 'ct_dst_ltm <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.05253104106972302, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.054441260744985676, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.05253104106972302, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.05348615090735435, 0.5256410256410257, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.06446991404011461, 0.6538461538461539, 'ct_srv_src <= 4.5\ngini = 0.405\nsamples = 78\nvalue = [22, 56]\nclass = 1'),
#  Text(0.05682903533906399, 0.6282051282051282, 'ct_srv_src <= 1.5\ngini = 0.305\nsamples = 48\nvalue = [9, 39]\nclass = 1'),
#  Text(0.054918815663801336, 0.6025641025641025, 'ct_srv_dst <= 5.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.05396370582617001, 0.5769230769230769, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.055873925501432664, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.05873925501432665, 0.6025641025641025, 'dur <= 0.0\ngini = 0.263\nsamples = 45\nvalue = [7, 38]\nclass = 1'),
#  Text(0.05778414517669532, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.059694364851957976, 0.5769230769230769, 'ct_src_ ltm <= 1.5\ngini = 0.236\nsamples = 44\nvalue = [6, 38]\nclass = 1'),
#  Text(0.05730659025787966, 0.5512820512820513, 'dur <= 0.0\ngini = 0.133\nsamples = 28\nvalue = [2, 26]\nclass = 1'),
#  Text(0.055396370582617004, 0.5256410256410257, 'ct_srv_dst <= 6.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.054441260744985676, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.05635148042024833, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.05921680993314231, 0.5256410256410257, 'ct_srv_dst <= 5.5\ngini = 0.074\nsamples = 26\nvalue = [1, 25]\nclass = 1'),
#  Text(0.05826170009551098, 0.5, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]\nclass = 1'),
#  Text(0.06017191977077364, 0.5, 'Sload <= 86666664.0\ngini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = 1'),
#  Text(0.05921680993314231, 0.47435897435897434, 'Sload <= 64380950.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = 1'),
#  Text(0.05826170009551098, 0.44871794871794873, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1'),
#  Text(0.06017191977077364, 0.44871794871794873, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.061127029608404965, 0.47435897435897434, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = 1'),
#  Text(0.06208213944603629, 0.5512820512820513, 'ct_srv_dst <= 5.5\ngini = 0.375\nsamples = 16\nvalue = [4, 12]\nclass = 1'),
#  Text(0.061127029608404965, 0.5256410256410257, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1'),
#  Text(0.06303724928366762, 0.5256410256410257, 'ct_srv_src <= 2.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]\nclass = 1'),
#  Text(0.06208213944603629, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.06399235912129896, 0.5, 'ct_srv_dst <= 6.5\ngini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = 1'),
#  Text(0.06303724928366762, 0.47435897435897434, 'ct_dst_src_ltm <= 1.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = 1'),
#  Text(0.06208213944603629, 0.44871794871794873, 'Sload <= 78000000.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = 1'),
#  Text(0.061127029608404965, 0.4230769230769231, 'Sload <= 46800000.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = 0'),
#  Text(0.06017191977077364, 0.3974358974358974, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.06208213944603629, 0.3974358974358974, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.06303724928366762, 0.4230769230769231, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.06399235912129896, 0.44871794871794873, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.06494746895893028, 0.47435897435897434, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.07211079274116523, 0.6282051282051282, 'dur <= 0.0\ngini = 0.491\nsamples = 30\nvalue = [13, 17]\nclass = 1'),
#  Text(0.06972301814708691, 0.6025641025641025, 'ct_dst_sport_ltm <= 1.5\ngini = 0.375\nsamples = 16\nvalue = [4, 12]\nclass = 1'),
#  Text(0.06876790830945559, 0.5769230769230769, 'ct_src_dport_ltm <= 1.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]\nclass = 1'),
#  Text(0.06781279847182425, 0.5512820512820513, 'ct_srv_dst <= 5.5\ngini = 0.397\nsamples = 11\nvalue = [3, 8]\nclass = 1'),
#  Text(0.06685768863419293, 0.5256410256410257, 'Sload <= 81714286.0\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = 1'),
#  Text(0.0659025787965616, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.06781279847182425, 0.5, 'Sload <= 121333328.0\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = 1'),
#  Text(0.06685768863419293, 0.47435897435897434, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.06876790830945559, 0.47435897435897434, 'dur <= 0.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = 1'),
#  Text(0.06781279847182425, 0.44871794871794873, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.06972301814708691, 0.44871794871794873, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.06876790830945559, 0.5256410256410257, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.06972301814708691, 0.5512820512820513, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.07067812798471824, 0.5769230769230769, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(0.07449856733524356, 0.6025641025641025, 'ct_src_ ltm <= 1.5\ngini = 0.459\nsamples = 14\nvalue = [9, 5]\nclass = 0'),
#  Text(0.0725883476599809, 0.5769230769230769, 'ct_dst_ltm <= 1.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = 1'),
#  Text(0.07163323782234957, 0.5512820512820513, 'Sload <= 39709090.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = 0'),
#  Text(0.07067812798471824, 0.5256410256410257, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.0725883476599809, 0.5256410256410257, 'dur <= 0.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.07163323782234957, 0.5, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.07354345749761222, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.07354345749761222, 0.5512820512820513, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.07640878701050621, 0.5769230769230769, 'ct_src_ ltm <= 2.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = 0'),
#  Text(0.07545367717287488, 0.5512820512820513, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.07736389684813753, 0.5512820512820513, 'ct_dst_src_ltm <= 2.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = 0'),
#  Text(0.07640878701050621, 0.5256410256410257, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.07831900668576887, 0.5256410256410257, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.14035264446036294, 0.8333333333333334, 'ct_srv_src <= 18.5\ngini = 0.448\nsamples = 510\nvalue = [337, 173]\nclass = 0'),
#  Text(0.13457348376313277, 0.8076923076923077, 'ct_dst_sport_ltm <= 1.5\ngini = 0.421\nsamples = 481\nvalue = [336, 145]\nclass = 0'),
#  Text(0.1258804918815664, 0.782051282051282, 'ct_srv_dst <= 8.5\ngini = 0.356\nsamples = 401\nvalue = [308, 93]\nclass = 0'),
#  Text(0.1113598376313276, 0.7564102564102564, 'smeansz <= 43.5\ngini = 0.431\nsamples = 286\nvalue = [196, 90]\nclass = 0'),
#  Text(0.09652578796561605, 0.7307692307692307, 'ct_dst_src_ltm <= 2.5\ngini = 0.333\nsamples = 142\nvalue = [112, 30]\nclass = 0'),
#  Text(0.09276504297994269, 0.7051282051282052, 'smeansz <= 38.5\ngini = 0.291\nsamples = 130\nvalue = [107, 23]\nclass = 0'),
#  Text(0.09180993314231137, 0.6794871794871795, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.09372015281757402, 0.6794871794871795, 'ct_srv_dst <= 4.5\ngini = 0.274\nsamples = 128\nvalue = [107, 21]\nclass = 0'),
#  Text(0.09276504297994269, 0.6538461538461539, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]\nclass = 0'),
#  Text(0.09467526265520534, 0.6538461538461539, 'ct_srv_dst <= 6.5\ngini = 0.309\nsamples = 110\nvalue = [89, 21]\nclass = 0'),
#  Text(0.09001910219675263, 0.6282051282051282, 'ct_srv_src <= 10.5\ngini = 0.385\nsamples = 50\nvalue = [37, 13]\nclass = 0'),
#  Text(0.08643744030563515, 0.6025641025641025, 'Sload <= 65000000.0\ngini = 0.469\nsamples = 16\nvalue = [10, 6]\nclass = 0'),
#  Text(0.0830945558739255, 0.5769230769230769, 'dur <= 0.0\ngini = 0.5\nsamples = 10\nvalue = [5, 5]\nclass = 0'),
#  Text(0.08118433619866285, 0.5512820512820513, 'ct_src_ ltm <= 3.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = 1'),
#  Text(0.08022922636103152, 0.5256410256410257, 'ct_dst_src_ltm <= 1.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = 1'),
#  Text(0.07927411652340019, 0.5, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.08118433619866285, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.08213944603629417, 0.5256410256410257, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.08500477554918816, 0.5512820512820513, 'ct_dst_ltm <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(0.08404966571155682, 0.5256410256410257, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.08595988538681948, 0.5256410256410257, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.08978032473734479, 0.5769230769230769, 'dur <= 0.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = 0'),
#  Text(0.08882521489971347, 0.5512820512820513, 'dur <= 0.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.08787010506208214, 0.5256410256410257, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.08978032473734479, 0.5256410256410257, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.09073543457497613, 0.5512820512820513, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.0936007640878701, 0.6025641025641025, 'ct_srv_src <= 12.5\ngini = 0.327\nsamples = 34\nvalue = [27, 7]\nclass = 0'),
#  Text(0.09264565425023878, 0.5769230769230769, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = 0'),
#  Text(0.09455587392550144, 0.5769230769230769, 'ct_src_ ltm <= 3.5\ngini = 0.444\nsamples = 21\nvalue = [14, 7]\nclass = 0'),
#  Text(0.09264565425023878, 0.5512820512820513, 'ct_srv_src <= 13.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]\nclass = 0'),
#  Text(0.09169054441260745, 0.5256410256410257, 'Sload <= 130000000.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = 0'),
#  Text(0.09073543457497613, 0.5, 'ct_src_dport_ltm <= 1.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = 0'),
#  Text(0.08978032473734479, 0.47435897435897434, 'ct_src_ ltm <= 2.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = 0'),
#  Text(0.08882521489971347, 0.44871794871794873, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.09073543457497613, 0.44871794871794873, 'Sload <= 53181818.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.08978032473734479, 0.4230769230769231, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.09169054441260745, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.09169054441260745, 0.47435897435897434, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.09264565425023878, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.0936007640878701, 0.5256410256410257, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0'),
#  Text(0.0964660936007641, 0.5512820512820513, 'dur <= 0.0\ngini = 0.5\nsamples = 8\nvalue = [4, 4]\nclass = 0'),
#  Text(0.09551098376313276, 0.5256410256410257, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.09742120343839542, 0.5256410256410257, 'ct_dst_ltm <= 1.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = 1'),
#  Text(0.0964660936007641, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.09837631327602674, 0.5, 'ct_src_ ltm <= 4.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = 1'),
#  Text(0.09742120343839542, 0.47435897435897434, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.09933142311365807, 0.47435897435897434, 'Sload <= 36467532.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = 0'),
#  Text(0.09837631327602674, 0.44871794871794873, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.10028653295128939, 0.44871794871794873, 'Sload <= 83200000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.09933142311365807, 0.4230769230769231, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.10124164278892073, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.09933142311365807, 0.6282051282051282, 'ct_srv_dst <= 7.5\ngini = 0.231\nsamples = 60\nvalue = [52, 8]\nclass = 0'),
#  Text(0.09742120343839542, 0.6025641025641025, 'ct_src_ ltm <= 1.5\ngini = 0.053\nsamples = 37\nvalue = [36, 1]\nclass = 0'),
#  Text(0.0964660936007641, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.09837631327602674, 0.5769230769230769, 'gini = 0.0\nsamples = 36\nvalue = [36, 0]\nclass = 0'),
#  Text(0.10124164278892073, 0.6025641025641025, 'ct_srv_src <= 11.5\ngini = 0.423\nsamples = 23\nvalue = [16, 7]\nclass = 0'),
#  Text(0.10028653295128939, 0.5769230769230769, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = 1'),
#  Text(0.10219675262655205, 0.5769230769230769, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]\nclass = 0'),
#  Text(0.10028653295128939, 0.7051282051282052, 'Sload <= 27181818.0\ngini = 0.486\nsamples = 12\nvalue = [5, 7]\nclass = 1'),
#  Text(0.09933142311365807, 0.6794871794871795, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.10124164278892073, 0.6794871794871795, 'ct_srv_src <= 13.5\ngini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = 1'),
#  Text(0.10028653295128939, 0.6538461538461539, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1'),
#  Text(0.10219675262655205, 0.6538461538461539, 'ct_srv_dst <= 5.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = 0'),
#  Text(0.10124164278892073, 0.6282051282051282, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.10315186246418338, 0.6282051282051282, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.12619388729703915, 0.7307692307692307, 'ct_srv_src <= 11.5\ngini = 0.486\nsamples = 144\nvalue = [84, 60]\nclass = 0'),
#  Text(0.11867239732569246, 0.7051282051282052, 'ct_srv_dst <= 4.5\ngini = 0.415\nsamples = 109\nvalue = [77, 32]\nclass = 0'),
#  Text(0.11079274116523401, 0.6794871794871795, 'ct_dst_ltm <= 1.5\ngini = 0.408\nsamples = 21\nvalue = [6, 15]\nclass = 1'),
#  Text(0.1069723018147087, 0.6538461538461539, 'dur <= 0.0\ngini = 0.26\nsamples = 13\nvalue = [2, 11]\nclass = 1'),
#  Text(0.10506208213944604, 0.6282051282051282, 'ct_srv_dst <= 3.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.1041069723018147, 0.6025641025641025, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.10601719197707736, 0.6025641025641025, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.10888252148997135, 0.6282051282051282, 'Sload <= 49111110.0\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = 1'),
#  Text(0.10792741165234002, 0.6025641025641025, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1'),
#  Text(0.10983763132760267, 0.6025641025641025, 'Sload <= 55714286.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = 1'),
#  Text(0.10888252148997135, 0.5769230769230769, 'ct_srv_src <= 8.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.10792741165234002, 0.5512820512820513, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.10983763132760267, 0.5512820512820513, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.11079274116523401, 0.5769230769230769, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(0.11461318051575932, 0.6538461538461539, 'ct_srv_src <= 7.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]\nclass = 0'),
#  Text(0.11270296084049666, 0.6282051282051282, 'Sload <= 39709090.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(0.11174785100286533, 0.6025641025641025, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.11365807067812798, 0.6025641025641025, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.11652340019102196, 0.6282051282051282, 'Sload <= 64380950.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = 1'),
#  Text(0.11556829035339064, 0.6025641025641025, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.1174785100286533, 0.6025641025641025, 'Sload <= 76266664.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.11652340019102196, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.11843361986628462, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.1265520534861509, 0.6794871794871795, 'ct_dst_ltm <= 5.5\ngini = 0.312\nsamples = 88\nvalue = [71, 17]\nclass = 0'),
#  Text(0.1255969436485196, 0.6538461538461539, 'ct_srv_dst <= 6.5\ngini = 0.275\nsamples = 85\nvalue = [71, 14]\nclass = 0'),
#  Text(0.12464183381088825, 0.6282051282051282, 'ct_srv_src <= 9.5\ngini = 0.354\nsamples = 61\nvalue = [47, 14]\nclass = 0'),
#  Text(0.12368672397325692, 0.6025641025641025, 'ct_srv_dst <= 5.5\ngini = 0.393\nsamples = 52\nvalue = [38, 14]\nclass = 0'),
#  Text(0.12034383954154727, 0.5769230769230769, 'ct_srv_src <= 8.5\ngini = 0.313\nsamples = 36\nvalue = [29, 7]\nclass = 0'),
#  Text(0.11843361986628462, 0.5512820512820513, 'ct_srv_src <= 7.5\ngini = 0.231\nsamples = 30\nvalue = [26, 4]\nclass = 0'),
#  Text(0.1174785100286533, 0.5256410256410257, 'Sload <= 39709090.0\ngini = 0.332\nsamples = 19\nvalue = [15, 4]\nclass = 0'),
#  Text(0.11652340019102196, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0'),
#  Text(0.11843361986628462, 0.5, 'Sload <= 49111110.0\ngini = 0.426\nsamples = 13\nvalue = [9, 4]\nclass = 0'),
#  Text(0.1174785100286533, 0.47435897435897434, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.11938872970391595, 0.47435897435897434, 'dur <= 0.0\ngini = 0.298\nsamples = 11\nvalue = [9, 2]\nclass = 0'),
#  Text(0.11843361986628462, 0.44871794871794873, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.12034383954154727, 0.44871794871794873, 'ct_src_ ltm <= 2.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = 0'),
#  Text(0.11938872970391595, 0.4230769230769231, 'dur <= 0.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = 0'),
#  Text(0.11843361986628462, 0.3974358974358974, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.12034383954154727, 0.3974358974358974, 'dur <= 0.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.11938872970391595, 0.3717948717948718, 'ct_dst_src_ltm <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.11843361986628462, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.12034383954154727, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.12129894937917861, 0.3717948717948718, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.12129894937917861, 0.4230769230769231, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.11938872970391595, 0.5256410256410257, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = 0'),
#  Text(0.12225405921680993, 0.5512820512820513, 'ct_dst_ltm <= 2.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = 0'),
#  Text(0.12129894937917861, 0.5256410256410257, 'Sload <= 52825396.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = 1'),
#  Text(0.12034383954154727, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.12225405921680993, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.12320916905444126, 0.5256410256410257, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.12702960840496658, 0.5769230769230769, 'ct_srv_src <= 7.5\ngini = 0.492\nsamples = 16\nvalue = [9, 7]\nclass = 0'),
#  Text(0.12607449856733524, 0.5512820512820513, 'Sload <= 64380950.0\ngini = 0.375\nsamples = 12\nvalue = [9, 3]\nclass = 0'),
#  Text(0.1251193887297039, 0.5256410256410257, 'dur <= 0.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = 0'),
#  Text(0.12416427889207259, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.12607449856733524, 0.5, 'ct_srv_src <= 6.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(0.1251193887297039, 0.47435897435897434, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.12702960840496658, 0.47435897435897434, 'dur <= 0.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.12607449856733524, 0.44871794871794873, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.1279847182425979, 0.44871794871794873, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.12702960840496658, 0.5256410256410257, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0'),
#  Text(0.1279847182425979, 0.5512820512820513, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(0.1255969436485196, 0.6025641025641025, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = 0'),
#  Text(0.1265520534861509, 0.6282051282051282, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]\nclass = 0'),
#  Text(0.12750716332378223, 0.6538461538461539, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.13371537726838587, 0.7051282051282052, 'ct_srv_dst <= 5.5\ngini = 0.32\nsamples = 35\nvalue = [7, 28]\nclass = 1'),
#  Text(0.13276026743075453, 0.6794871794871795, 'ct_src_ ltm <= 4.5\ngini = 0.475\nsamples = 18\nvalue = [7, 11]\nclass = 1'),
#  Text(0.1318051575931232, 0.6538461538461539, 'ct_src_dport_ltm <= 1.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]\nclass = 1'),
#  Text(0.1308500477554919, 0.6282051282051282, 'ct_src_ ltm <= 3.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = 1'),
#  Text(0.12989493791786055, 0.6025641025641025, 'Sload <= 72800000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.12893982808022922, 0.5769230769230769, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.1308500477554919, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.1318051575931232, 0.6025641025641025, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.13276026743075453, 0.6282051282051282, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = 1'),
#  Text(0.13371537726838587, 0.6538461538461539, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.1346704871060172, 0.6794871794871795, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]\nclass = 1'),
#  Text(0.14040114613180515, 0.7564102564102564, 'ct_src_ ltm <= 6.5\ngini = 0.051\nsamples = 115\nvalue = [112, 3]\nclass = 0'),
#  Text(0.13944603629417382, 0.7307692307692307, 'ct_src_ ltm <= 2.5\ngini = 0.034\nsamples = 114\nvalue = [112, 2]\nclass = 0'),
#  Text(0.1384909264565425, 0.7051282051282052, 'ct_srv_src <= 15.5\ngini = 0.219\nsamples = 16\nvalue = [14, 2]\nclass = 0'),
#  Text(0.13658070678127984, 0.6794871794871795, 'ct_srv_src <= 11.0\ngini = 0.133\nsamples = 14\nvalue = [13, 1]\nclass = 0'),
#  Text(0.1356255969436485, 0.6538461538461539, 'dur <= 0.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(0.1346704871060172, 0.6282051282051282, 'Sload <= 72800000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.13371537726838587, 0.6025641025641025, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.1356255969436485, 0.6025641025641025, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.13658070678127984, 0.6282051282051282, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.13753581661891118, 0.6538461538461539, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = 0'),
#  Text(0.14040114613180515, 0.6794871794871795, 'dur <= 0.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.13944603629417382, 0.6538461538461539, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.1413562559694365, 0.6538461538461539, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.14040114613180515, 0.7051282051282052, 'gini = 0.0\nsamples = 98\nvalue = [98, 0]\nclass = 0'),
#  Text(0.1413562559694365, 0.7307692307692307, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.14326647564469913, 0.782051282051282, 'ct_srv_src <= 8.0\ngini = 0.455\nsamples = 80\nvalue = [28, 52]\nclass = 1'),
#  Text(0.14231136580706782, 0.7564102564102564, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]\nclass = 0'),
#  Text(0.14422158548233047, 0.7564102564102564, 'Sload <= 29781818.0\ngini = 0.305\nsamples = 64\nvalue = [12, 52]\nclass = 1'),
#  Text(0.14326647564469913, 0.7307692307692307, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.1451766953199618, 0.7307692307692307, 'Sload <= 190000000.0\ngini = 0.231\nsamples = 60\nvalue = [8, 52]\nclass = 1'),
#  Text(0.14326647564469913, 0.7051282051282052, 'ct_srv_src <= 13.5\ngini = 0.137\nsamples = 54\nvalue = [4, 50]\nclass = 1'),
#  Text(0.14231136580706782, 0.6794871794871795, 'gini = 0.0\nsamples = 38\nvalue = [0, 38]\nclass = 1'),
#  Text(0.14422158548233047, 0.6794871794871795, 'ct_src_ ltm <= 4.5\ngini = 0.375\nsamples = 16\nvalue = [4, 12]\nclass = 1'),
#  Text(0.14326647564469913, 0.6538461538461539, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.1451766953199618, 0.6538461538461539, 'ct_srv_dst <= 10.5\ngini = 0.245\nsamples = 14\nvalue = [2, 12]\nclass = 1'),
#  Text(0.14422158548233047, 0.6282051282051282, 'ct_srv_dst <= 9.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = 1'),
#  Text(0.14326647564469913, 0.6025641025641025, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.1451766953199618, 0.6025641025641025, 'Sload <= 50700000.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = 0'),
#  Text(0.14422158548233047, 0.5769230769230769, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.14613180515759314, 0.5769230769230769, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.14613180515759314, 0.6282051282051282, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = 1'),
#  Text(0.14708691499522444, 0.7051282051282052, 'ct_srv_src <= 12.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = 0'),
#  Text(0.14613180515759314, 0.6794871794871795, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.14804202483285578, 0.6794871794871795, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.14613180515759314, 0.8076923076923077, 'ct_srv_src <= 26.5\ngini = 0.067\nsamples = 29\nvalue = [1, 28]\nclass = 1'),
#  Text(0.1451766953199618, 0.782051282051282, 'gini = 0.0\nsamples = 28\nvalue = [0, 28]\nclass = 1'),
#  Text(0.14708691499522444, 0.782051282051282, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.23595618655141923, 0.8589743589743589, 'ct_state_ttl <= 0.5\ngini = 0.214\nsamples = 7196\nvalue = [876, 6320]\nclass = 1'),
#  Text(0.15448901623686723, 0.8333333333333334, 'smeansz <= 1256.5\ngini = 0.119\nsamples = 173\nvalue = [162, 11]\nclass = 0'),
#  Text(0.15353390639923592, 0.8076923076923077, 'sttl <= 254.5\ngini = 0.012\nsamples = 163\nvalue = [162, 1]\nclass = 0'),
#  Text(0.15257879656160458, 0.782051282051282, 'gini = 0.0\nsamples = 160\nvalue = [160, 0]\nclass = 0'),
#  Text(0.15448901623686723, 0.782051282051282, 'ct_dst_ltm <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.15353390639923592, 0.7564102564102564, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.15544412607449856, 0.7564102564102564, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.15544412607449856, 0.8076923076923077, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = 1'),
#  Text(0.31742335686597123, 0.8333333333333334, 'ct_srv_dst <= 22.5\ngini = 0.183\nsamples = 7023\nvalue = [714, 6309]\nclass = 1'),
#  Text(0.20328630303471226, 0.8076923076923077, 'sbytes <= 201.0\ngini = 0.153\nsamples = 6767\nvalue = [566, 6201]\nclass = 1'),
#  Text(0.1608166189111748, 0.782051282051282, 'Sjit <= 30.426\ngini = 0.017\nsamples = 3223\nvalue = [27, 3196]\nclass = 1'),
#  Text(0.15735434574976123, 0.7564102564102564, 'dur <= 0.0\ngini = 0.015\nsamples = 3220\nvalue = [25, 3195]\nclass = 1'),
#  Text(0.1563992359121299, 0.7307692307692307, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.15830945558739254, 0.7307692307692307, 'ct_dst_sport_ltm <= 1.5\ngini = 0.015\nsamples = 3219\nvalue = [24, 3195]\nclass = 1'),
#  Text(0.15425023877745941, 0.7051282051282052, 'ct_src_dport_ltm <= 1.5\ngini = 0.069\nsamples = 643\nvalue = [23, 620]\nclass = 1'),
#  Text(0.15090735434574976, 0.6794871794871795, 'ct_srv_dst <= 14.5\ngini = 0.007\nsamples = 595\nvalue = [2, 593]\nclass = 1'),
#  Text(0.1489971346704871, 0.6538461538461539, 'sbytes <= 146.0\ngini = 0.003\nsamples = 593\nvalue = [1, 592]\nclass = 1'),
#  Text(0.14804202483285578, 0.6282051282051282, 'ct_srv_src <= 12.0\ngini = 0.142\nsamples = 13\nvalue = [1, 12]\nclass = 1'),
#  Text(0.14708691499522444, 0.6025641025641025, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]\nclass = 1'),
#  Text(0.1489971346704871, 0.6025641025641025, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.14995224450811842, 0.6282051282051282, 'gini = 0.0\nsamples = 580\nvalue = [0, 580]\nclass = 1'),
#  Text(0.15281757402101243, 0.6538461538461539, 'sbytes <= 181.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.1518624641833811, 0.6282051282051282, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.15377268385864373, 0.6282051282051282, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.15759312320916904, 0.6794871794871795, 'ct_srv_dst <= 15.5\ngini = 0.492\nsamples = 48\nvalue = [21, 27]\nclass = 1'),
#  Text(0.15663801337153774, 0.6538461538461539, 'ct_srv_src <= 3.5\ngini = 0.472\nsamples = 34\nvalue = [21, 13]\nclass = 0'),
#  Text(0.1556829035339064, 0.6282051282051282, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = 1'),
#  Text(0.15759312320916904, 0.6282051282051282, 'Sload <= 46952380.0\ngini = 0.269\nsamples = 25\nvalue = [21, 4]\nclass = 0'),
#  Text(0.15663801337153774, 0.6025641025641025, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.15854823304680038, 0.6025641025641025, 'ct_srv_src <= 6.5\ngini = 0.219\nsamples = 24\nvalue = [21, 3]\nclass = 0'),
#  Text(0.15663801337153774, 0.5769230769230769, 'ct_src_dport_ltm <= 2.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = 0'),
#  Text(0.1556829035339064, 0.5512820512820513, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.15759312320916904, 0.5512820512820513, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.16045845272206305, 0.5769230769230769, 'sbytes <= 166.0\ngini = 0.095\nsamples = 20\nvalue = [19, 1]\nclass = 0'),
#  Text(0.15950334288443171, 0.5512820512820513, 'sbytes <= 160.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = 0'),
#  Text(0.15854823304680038, 0.5256410256410257, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(0.16045845272206305, 0.5256410256410257, 'Sload <= 136666664.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.15950334288443171, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.16141356255969436, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.16141356255969436, 0.5512820512820513, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = 0'),
#  Text(0.15854823304680038, 0.6538461538461539, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]\nclass = 1'),
# ...
#  Text(0.3120821394460363, 0.6025641025641025, 'stcpb <= 65538408.0\ngini = 0.064\nsamples = 60\nvalue = [2, 58]\nclass = 1'),
#  Text(0.31017191977077363, 0.5769230769230769, 'dtcpb <= 723065136.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.3092168099331423, 0.5512820512820513, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.311127029608405, 0.5512820512820513, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.31399235912129897, 0.5769230769230769, 'Dload <= 7513.907\ngini = 0.034\nsamples = 58\nvalue = [1, 57]\nclass = 1'),
#  Text(0.3130372492836676, 0.5512820512820513, 'synack <= 0.041\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = 1'),
#  Text(0.3120821394460363, 0.5256410256410257, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.31399235912129897, 0.5256410256410257, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(0.3149474689589303, 0.5512820512820513, 'gini = 0.0\nsamples = 53\nvalue = [0, 53]\nclass = 1'),
#  Text(0.31399235912129897, 0.6025641025641025, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.37875841317454634, 0.7307692307692307, 'Sload <= 303200000.0\ngini = 0.335\nsamples = 931\nvalue = [198, 733]\nclass = 1'),
#  Text(0.35763173800143266, 0.7051282051282052, 'Spkts <= 11.0\ngini = 0.262\nsamples = 748\nvalue = [116, 632]\nclass = 1'),
#  Text(0.3423826259551098, 0.6794871794871795, 'ackdat <= 0.053\ngini = 0.325\nsamples = 479\nvalue = [98, 381]\nclass = 1'),
#  Text(0.3282108106494747, 0.6538461538461539, 'ct_dst_sport_ltm <= 1.5\ngini = 0.237\nsamples = 305\nvalue = [42, 263]\nclass = 1'),
#  Text(0.32725570081184335, 0.6282051282051282, 'ct_srv_src <= 21.5\ngini = 0.312\nsamples = 217\nvalue = [42, 175]\nclass = 1'),
#  Text(0.3241329393505253, 0.6025641025641025, 'ct_src_dport_ltm <= 8.0\ngini = 0.294\nsamples = 212\nvalue = [38, 174]\nclass = 1'),
#  Text(0.3207527459407832, 0.5769230769230769, 'Dload <= 12953.387\ngini = 0.275\nsamples = 207\nvalue = [34, 173]\nclass = 1'),
#  Text(0.31685768863419295, 0.5512820512820513, 'Sjit <= 25323.437\ngini = 0.245\nsamples = 196\nvalue = [28, 168]\nclass = 1'),
#  Text(0.3159025787965616, 0.5256410256410257, 'Dload <= 4937.53\ngini = 0.232\nsamples = 194\nvalue = [26, 168]\nclass = 1'),
#  Text(0.3109777936962751, 0.5, 'Dload <= 4791.218\ngini = 0.33\nsamples = 96\nvalue = [20, 76]\nclass = 1'),
#  Text(0.30757521489971346, 0.47435897435897434, 'ct_srv_dst <= 5.5\ngini = 0.292\nsamples = 90\nvalue = [16, 74]\nclass = 1'),
#  Text(0.30363538681948427, 0.44871794871794873, 'Sload <= 9439.292\ngini = 0.469\nsamples = 16\nvalue = [6, 10]\nclass = 1'),
#  Text(0.3026802769818529, 0.4230769230769231, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = 1'),
#  Text(0.3045904966571156, 0.4230769230769231, 'Sload <= 171531712.0\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = 0'),
#  Text(0.30363538681948427, 0.3974358974358974, 'ct_src_dport_ltm <= 1.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = 0'),
#  Text(0.3026802769818529, 0.3717948717948718, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.3045904966571156, 0.3717948717948718, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0'),
#  Text(0.3055456064947469, 0.3974358974358974, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.3115150429799427, 0.44871794871794873, 'ct_srv_dst <= 17.5\ngini = 0.234\nsamples = 74\nvalue = [10, 64]\nclass = 1'),
#  Text(0.31055993314231134, 0.4230769230769231, 'smeansz <= 103.0\ngini = 0.216\nsamples = 73\nvalue = [9, 64]\nclass = 1'),
#  Text(0.30745582617000955, 0.3974358974358974, 'Dload <= 3821.087\ngini = 0.415\nsamples = 17\nvalue = [5, 12]\nclass = 1'),
#  Text(0.30650071633237824, 0.3717948717948718, 'sbytes <= 582.0\ngini = 0.494\nsamples = 9\nvalue = [5, 4]\nclass = 0'),
#  Text(0.3055456064947469, 0.34615384615384615, 'ct_srv_src <= 14.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = 0'),
#  Text(0.3045904966571156, 0.32051282051282054, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.30650071633237824, 0.32051282051282054, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.30745582617000955, 0.34615384615384615, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.30841093600764086, 0.3717948717948718, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = 1'),
#  Text(0.3136640401146132, 0.3974358974358974, 'dur <= 0.0\ngini = 0.133\nsamples = 56\nvalue = [4, 52]\nclass = 1'),
#  Text(0.31127626552053483, 0.3717948717948718, 'ct_srv_dst <= 10.0\ngini = 0.278\nsamples = 18\nvalue = [3, 15]\nclass = 1'),
#  Text(0.3093660458452722, 0.34615384615384615, 'Sload <= 123714284.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.30841093600764086, 0.32051282051282054, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.3103211556829035, 0.32051282051282054, 'ct_srv_src <= 10.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.3093660458452722, 0.2948717948717949, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.31127626552053483, 0.2948717948717949, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.3131864851957975, 0.34615384615384615, 'sbytes <= 250.0\ngini = 0.124\nsamples = 15\nvalue = [1, 14]\nclass = 1'),
#  Text(0.3122313753581662, 0.32051282051282054, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]\nclass = 1'),
#  Text(0.31414159503342887, 0.32051282051282054, 'ct_src_dport_ltm <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.3131864851957975, 0.2948717948717949, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.3150967048710602, 0.2948717948717949, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.3160518147086915, 0.3717948717948718, 'smeansz <= 478.5\ngini = 0.051\nsamples = 38\nvalue = [1, 37]\nclass = 1'),
#  Text(0.3150967048710602, 0.34615384615384615, 'gini = 0.0\nsamples = 34\nvalue = [0, 34]\nclass = 1'),
#  Text(0.31700692454632284, 0.34615384615384615, 'dur <= 0.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = 1'),
#  Text(0.3160518147086915, 0.32051282051282054, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.31796203438395415, 0.32051282051282054, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.312470152817574, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.3143803724928367, 0.47435897435897434, 'synack <= 0.04\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = 0'),
#  Text(0.31342526265520537, 0.44871794871794873, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.315335482330468, 0.44871794871794873, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.32082736389684813, 0.5, 'Sjit <= 69.54\ngini = 0.115\nsamples = 98\nvalue = [6, 92]\nclass = 1'),
#  Text(0.3198722540592168, 0.47435897435897434, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.3217824737344795, 0.47435897435897434, 'Sload <= 37460.686\ngini = 0.098\nsamples = 97\nvalue = [5, 92]\nclass = 1'),
#  Text(0.31843958930276983, 0.44871794871794873, 'ct_src_dport_ltm <= 1.5\ngini = 0.046\nsamples = 84\nvalue = [2, 82]\nclass = 1'),
#  Text(0.31652936962750716, 0.4230769230769231, 'stcpb <= 3282532608.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.31557425978987586, 0.3974358974358974, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.31748447946513847, 0.3974358974358974, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.32034980897803245, 0.4230769230769231, 'Dload <= 5462.038\ngini = 0.024\nsamples = 81\nvalue = [1, 80]\nclass = 1'),
#  Text(0.31939469914040114, 0.3974358974358974, 'dur <= 0.339\ngini = 0.124\nsamples = 15\nvalue = [1, 14]\nclass = 1'),
#  Text(0.31843958930276983, 0.3717948717948718, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.32034980897803245, 0.3717948717948718, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]\nclass = 1'),
#  Text(0.3213049188156638, 0.3974358974358974, 'gini = 0.0\nsamples = 66\nvalue = [0, 66]\nclass = 1'),
#  Text(0.3251253581661891, 0.44871794871794873, 'ct_srv_src <= 11.0\ngini = 0.355\nsamples = 13\nvalue = [3, 10]\nclass = 1'),
#  Text(0.3241702483285578, 0.4230769230769231, 'tcprtt <= 0.081\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = 1'),
#  Text(0.3232151384909265, 0.3974358974358974, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = 1'),
#  Text(0.3251253581661891, 0.3974358974358974, 'synack <= 0.045\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.3241702483285578, 0.3717948717948718, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.32608046800382046, 0.3717948717948718, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.32608046800382046, 0.4230769230769231, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.31781279847182425, 0.5256410256410257, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.32464780324737347, 0.5512820512820513, 'Dpkts <= 9.0\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = 0'),
#  Text(0.3236926934097421, 0.5256410256410257, 'dbytes <= 1671.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = 0'),
#  Text(0.3227375835721108, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0'),
#  Text(0.32464780324737347, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.3256029130850048, 0.5256410256410257, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(0.32751313276026744, 0.5769230769230769, 'ct_dst_ltm <= 10.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = 0'),
#  Text(0.3265580229226361, 0.5512820512820513, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.32846824259789875, 0.5512820512820513, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.3303784622731614, 0.6025641025641025, 'Sjit <= 3440.147\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = 0'),
#  Text(0.32942335243553006, 0.5769230769230769, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(0.33133357211079273, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.329165920487106, 0.6282051282051282, 'gini = 0.0\nsamples = 88\nvalue = [0, 88]\nclass = 1'),
#  Text(0.356554441260745, 0.6538461538461539, 'ct_srv_dst <= 8.5\ngini = 0.437\nsamples = 174\nvalue = [56, 118]\nclass = 1'),
#  Text(0.34930157593123207, 0.6282051282051282, 'dtcpb <= 3785334528.0\ngini = 0.48\nsamples = 135\nvalue = [54, 81]\nclass = 1'),
#  Text(0.33957139446036294, 0.6025641025641025, 'stcpb <= 1432380608.0\ngini = 0.46\nsamples = 120\nvalue = [43, 77]\nclass = 1'),
#  Text(0.3332437917860554, 0.5769230769230769, 'Sjit <= 3613.034\ngini = 0.271\nsamples = 31\nvalue = [5, 26]\nclass = 1'),
#  Text(0.3322886819484241, 0.5512820512820513, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]\nclass = 1'),
#  Text(0.3341989016236867, 0.5512820512820513, 'stcpb <= 940346720.0\ngini = 0.444\nsamples = 15\nvalue = [5, 10]\nclass = 1'),
#  Text(0.3332437917860554, 0.5256410256410257, 'smeansz <= 59.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = 0'),
#  Text(0.3322886819484241, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.3341989016236867, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.33515401146131807, 0.5256410256410257, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = 1'),
#  Text(0.3458989971346705, 0.5769230769230769, 'synack <= 0.054\ngini = 0.489\nsamples = 89\nvalue = [38, 51]\nclass = 1'),
#  Text(0.33945200573065903, 0.5512820512820513, 'Dload <= 2353.42\ngini = 0.451\nsamples = 67\nvalue = [23, 44]\nclass = 1'),
#  Text(0.33849689589302767, 0.5256410256410257, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.34040711556829034, 0.5256410256410257, 'stcpb <= 3361760512.0\ngini = 0.412\nsamples = 62\nvalue = [18, 44]\nclass = 1'),
#  Text(0.3361091212989494, 0.5, 'stcpb <= 1473905472.0\ngini = 0.298\nsamples = 44\nvalue = [8, 36]\nclass = 1'),
#  Text(0.33515401146131807, 0.47435897435897434, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.3370642311365807, 0.47435897435897434, 'ackdat <= 0.067\ngini = 0.273\nsamples = 43\nvalue = [7, 36]\nclass = 1'),
#  Text(0.3341989016236867, 0.44871794871794873, 'ackdat <= 0.059\ngini = 0.432\nsamples = 19\nvalue = [6, 13]\nclass = 1'),
#  Text(0.3332437917860554, 0.4230769230769231, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = 1'),
#  Text(0.33515401146131807, 0.4230769230769231, 'ct_dst_ltm <= 2.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = 0'),
#  Text(0.3341989016236867, 0.3974358974358974, 'synack <= 0.047\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = 0'),
#  Text(0.3332437917860554, 0.3717948717948718, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.33515401146131807, 0.3717948717948718, 'Sload <= 8946.674\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(0.3341989016236867, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.3361091212989494, 0.34615384615384615, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.3361091212989494, 0.3974358974358974, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(0.3399295606494747, 0.44871794871794873, 'dtcpb <= 240502696.0\ngini = 0.08\nsamples = 24\nvalue = [1, 23]\nclass = 1'),
#  Text(0.33897445081184335, 0.4230769230769231, 'synack <= 0.044\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.33801934097421205, 0.3974358974358974, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.3399295606494747, 0.3974358974358974, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.340884670487106, 0.4230769230769231, 'gini = 0.0\nsamples = 22\nvalue = [0, 22]\nclass = 1'),
#  Text(0.3447051098376313, 0.5, 'synack <= 0.042\ngini = 0.494\nsamples = 18\nvalue = [10, 8]\nclass = 0'),
#  Text(0.3427948901623687, 0.47435897435897434, 'ct_src_dport_ltm <= 1.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]\nclass = 1'),
#  Text(0.34183978032473733, 0.44871794871794873, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.34375, 0.44871794871794873, 'dtcpb <= 3052526976.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = 1'),
#  Text(0.3427948901623687, 0.4230769230769231, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = 1'),
#  Text(0.3447051098376313, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.346615329512894, 0.47435897435897434, 'stcpb <= 4041159936.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = 0'),
#  Text(0.34566021967526267, 0.44871794871794873, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = 0'),
#  Text(0.3475704393505253, 0.44871794871794873, 'tcprtt <= 0.105\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(0.346615329512894, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.34852554918815665, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.35234598853868193, 0.5512820512820513, 'dmeansz <= 44.5\ngini = 0.434\nsamples = 22\nvalue = [15, 7]\nclass = 0'),
#  Text(0.3504357688634193, 0.5256410256410257, 'stcpb <= 2314176384.0\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = 1'),
#  Text(0.34948065902578795, 0.5, 'dur <= 2.12\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.34852554918815665, 0.47435897435897434, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.3504357688634193, 0.47435897435897434, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.3513908787010506, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1'),
#  Text(0.3542562082139446, 0.5256410256410257, 'ct_dst_ltm <= 4.0\ngini = 0.133\nsamples = 14\nvalue = [13, 1]\nclass = 0'),
#  Text(0.3533010983763133, 0.5, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = 0'),
#  Text(0.3552113180515759, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(0.35903175740210125, 0.6025641025641025, 'dur <= 0.601\ngini = 0.391\nsamples = 15\nvalue = [11, 4]\nclass = 0'),
#  ...]

# %%
DecisionTree1 = DecisionTreeClassifier(max_depth=5)
DecisionTree1.fit(X_train,Y_train) #fitting the preprocessed data with the decision tree algorithm

dt_ytrain_pred = DecisionTree1.predict(X_train)
dt_ytest_pred = DecisionTree1.predict(X_test)

print('Training Score:',accuracy_score(Y_train,dt_ytrain_pred))
print('Testing Score:',accuracy_score(Y_test,dt_ytest_pred))
# Out:
# Training Score: 0.9970538250940333
# Testing Score: 0.9972779078988621

# %%
from sklearn.tree import plot_tree

fig = plt.figure(figsize=(25,20))
plot_tree(DecisionTree1,filled=True,rounded=True,feature_names=data.columns,class_names=['0','1'])
# Out:
# [Text(0.355, 0.9166666666666666, 'sttl <= 61.0\ngini = 0.5\nsamples = 1084457\nvalue = [542393, 542064]\nclass = 0'),
#  Text(0.08, 0.75, 'ct_state_ttl <= 0.5\ngini = 0.004\nsamples = 539058\nvalue = [538023, 1035]\nclass = 0'),
#  Text(0.04, 0.5833333333333334, 'gini = 0.0\nsamples = 536625\nvalue = [536625, 0]\nclass = 0'),
#  Text(0.12, 0.5833333333333334, 'ct_srv_src <= 6.0\ngini = 0.489\nsamples = 2433\nvalue = [1398, 1035]\nclass = 0'),
#  Text(0.08, 0.4166666666666667, 'gini = 0.0\nsamples = 1398\nvalue = [1398, 0]\nclass = 0'),
#  Text(0.16, 0.4166666666666667, 'gini = 0.0\nsamples = 1035\nvalue = [0, 1035]\nclass = 1'),
#  Text(0.63, 0.75, 'smeansz <= 45.5\ngini = 0.016\nsamples = 545399\nvalue = [4370, 541029]\nclass = 1'),
#  Text(0.38, 0.5833333333333334, 'ct_state_ttl <= 2.5\ngini = 0.334\nsamples = 4932\nvalue = [1047, 3885]\nclass = 1'),
#  Text(0.24, 0.4166666666666667, 'ct_state_ttl <= 0.5\ngini = 0.166\nsamples = 4019\nvalue = [366, 3653]\nclass = 1'),
#  Text(0.2, 0.25, 'gini = 0.0\nsamples = 192\nvalue = [192, 0]\nclass = 0'),
#  Text(0.28, 0.25, 'proto <= 48.0\ngini = 0.087\nsamples = 3827\nvalue = [174, 3653]\nclass = 1'),
#  Text(0.24, 0.08333333333333333, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = 0'),
#  Text(0.32, 0.08333333333333333, 'gini = 0.082\nsamples = 3817\nvalue = [164, 3653]\nclass = 1'),
#  Text(0.52, 0.4166666666666667, 'proto <= 117.0\ngini = 0.379\nsamples = 913\nvalue = [681, 232]\nclass = 0'),
#  Text(0.44, 0.25, 'dbytes <= 3931179.0\ngini = 0.006\nsamples = 681\nvalue = [679, 2]\nclass = 0'),
#  Text(0.4, 0.08333333333333333, 'gini = 0.0\nsamples = 679\nvalue = [679, 0]\nclass = 0'),
#  Text(0.48, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(0.6, 0.25, 'Sload <= 53485714.0\ngini = 0.017\nsamples = 232\nvalue = [2, 230]\nclass = 1'),
#  Text(0.56, 0.08333333333333333, 'gini = 0.0\nsamples = 230\nvalue = [0, 230]\nclass = 1'),
#  Text(0.64, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(0.88, 0.5833333333333334, 'state <= 9.5\ngini = 0.012\nsamples = 540467\nvalue = [3323, 537144]\nclass = 1'),
#  Text(0.84, 0.4166666666666667, 'state <= 2.5\ngini = 0.012\nsamples = 540376\nvalue = [3232, 537144]\nclass = 1'),
#  Text(0.76, 0.25, 'synack <= 0.101\ngini = 0.15\nsamples = 4641\nvalue = [378, 4263]\nclass = 1'),
#  Text(0.72, 0.08333333333333333, 'gini = 0.063\nsamples = 4370\nvalue = [142, 4228]\nclass = 1'),
#  Text(0.8, 0.08333333333333333, 'gini = 0.225\nsamples = 271\nvalue = [236, 35]\nclass = 0'),
#  Text(0.92, 0.25, 'synack <= 0.068\ngini = 0.011\nsamples = 535735\nvalue = [2854, 532881]\nclass = 1'),
#  Text(0.88, 0.08333333333333333, 'gini = 0.005\nsamples = 442973\nvalue = [1202, 441771]\nclass = 1'),
#  Text(0.96, 0.08333333333333333, 'gini = 0.035\nsamples = 92762\nvalue = [1652, 91110]\nclass = 1'),
#  Text(0.92, 0.4166666666666667, 'gini = 0.0\nsamples = 91\nvalue = [91, 0]\nclass = 0')]

# %% [markdown]
# 5. Gaussian Naive Bayes'

# %%
gnb = GaussianNB()
gnb.fit(X_train, Y_train)

gnb_ytrain_pred = gnb.predict(X_train)
gnb_ytest_pred = gnb.predict(X_test)

print('Training Score:',accuracy_score(Y_train,gnb_ytrain_pred))
print('Testing Score:',accuracy_score(Y_test,gnb_ytest_pred))

cross_val(GaussianNB(),data)

# %% [markdown]
# 7. Support Vector Machines(SVM)

# %%
SVM = SVC()
SVM.fit(X_train, Y_train)

svm_ytrain_pred = SVM.predict(X_train)
svm_ytest_pred = SVM.predict(X_test)

print('Training Score:',accuracy_score(Y_train,svm_ytrain_pred))
print('Testing Score:',accuracy_score(Y_test,svm_ytest_pred))

cross_val(SVC(),data)

# %% [markdown]
# # **Dimensionality Reduction**

# %% [markdown]
# 1. Principal Component Analysis(PCA):

# %%
len(data.columns)
# Out:
# 36

# %%
from sklearn.decomposition import PCA
pca_n = []
pca_n_f1 = []
pca_attr = []
for i in range(1,36):
  pca = PCA(n_components = i)
  pca_x_train = pca.fit_transform(X_train)
  pca_x_test = pca.fit_transform(X_test)
  pca_attr.append(pca.explained_variance_ratio_)
  # # explained_variance = pca.explained_variance_ratio_
  # print(explained_variance)
  classifier = LogisticRegression()
  classifier.fit(pca_x_train, Y_train)
  classifier_pred = classifier.predict(pca_x_test)
  pca_n.append(i)
  pca_n_f1.append(f1_score(Y_test,classifier_pred))

plt.scatter(x=pca_n, y=pca_n_f1)

best_pca_n = pca_n_f1.index(max(pca_n_f1)) + 1
print('\nBest n value: ',best_pca_n)
print('Variance Ratio:',pca_attr[best_pca_n - 1])
plt.scatter(x=best_pca_n, y=pca_n_f1[best_pca_n - 1], color='red')
pca_n_f1.pop(best_pca_n -1)
sbest_pca_n = pca_n_f1.index(max(pca_n_f1)) + 1
print('\nSecond Best n value: ',sbest_pca_n)
print('Variance Ratio:',pca_attr[sbest_pca_n - 1])
plt.scatter(x=sbest_pca_n, y=pca_n_f1[sbest_pca_n - 1], color='red')
plt.show()
# Out:
# Best n value:  3
# Variance Ratio: [7.93374162e-01 2.06034367e-01 5.86866955e-04]
#
# Second Best n value:  3
# Variance Ratio: [7.93374162e-01 2.06034367e-01 5.86866955e-04]

# %%
pca.components_
# Out:
# array([[-5.54676039e-10,  4.78132721e-10,  2.05695037e-11, ...,
#          2.16930198e-12,  1.17451637e-11,  2.29113611e-11],
#        [-2.25356214e-12,  1.87880969e-12,  7.87705643e-12, ...,
#          4.69624446e-12,  4.76867329e-12, -1.48883181e-12],
#        [ 6.90656254e-10,  5.59555147e-09, -1.90553746e-09, ...,
#          3.89327666e-09,  2.13904592e-09,  3.24306553e-09],
#        ...,
#        [ 1.23607593e-04,  2.76444391e-04,  6.99520521e-06, ...,
#         -7.40553702e-04, -2.36257976e-03,  3.69366634e-04],
#        [ 1.23183668e-04,  4.53712759e-03, -9.86807787e-06, ...,
#         -2.21840849e-04, -1.78510928e-04,  1.60980880e-04],
#        [-1.58158642e-05, -4.46358464e-05,  2.04734462e-07, ...,
#          1.41325750e-04, -1.39246214e-04, -4.02741794e-05]])

# %%
from sklearn.decomposition import PCA
sbest_pca_n=3
pca = PCA(n_components=sbest_pca_n)

pca_data = pca.fit_transform(data)
pca_x_train = pca.fit_transform(X_train)

classifier = LogisticRegression()
classifier.fit(pca_x_train, Y_train)
cross_val(LogisticRegression() , pca_data)
# Out:
# ----------------- After cross validation -----------------
# Training Score: 0.7566690177656216
# Testing Score: 0.7566665584712579
#               precision    recall  f1-score   support
#
#            0       0.68      0.99      0.80    677786
#            1       0.98      0.52      0.68    677786
#
#     accuracy                           0.76   1355572
#    macro avg       0.83      0.76      0.74   1355572
# weighted avg       0.83      0.76      0.74   1355572

# %% [markdown]
# PCA forms 3 linear equations, which each attribute having some coefficient. This coefficient determines how important a variable is for the final prediction

# %%
print('AttributeName   PCA1   PCA2   PCA3')
attributeweights = {}
attributeimportance = {}
pcasum = [sum(abs(pca.components_[0])),sum(abs(pca.components_[1])),sum(abs(pca.components_[2]))]
for i in range(len(data.columns)):
    attributeweights[data.columns[i]] = [pca.components_[0][i],pca.components_[1][i],pca.components_[2][i]]
    attributeimportance[data.columns[i]] = abs(pca.components_[0][i])/pcasum[0]+abs(pca.components_[1][i])/pcasum[1]+abs(pca.components_[2][i])/pcasum[2]
    print(data.columns[i],'\t',pca.components_[0][i],'\t',pca.components_[1][i],'\t',pca.components_[2][i])
# Out:
# AttributeName   PCA1   PCA2   PCA3
# proto 	 -5.31165442603976e-10 	 -1.2029385772281977e-12 	 2.9788406728399397e-10
# state 	 4.756067170828796e-10 	 1.7806200453017851e-12 	 5.238499404980788e-09
# dur 	 1.2830549327506897e-11 	 -2.3361675334946367e-12 	 -1.8713884454113884e-09
# sbytes 	 1.2931459424734713e-06 	 -7.74484868587323e-09 	 -1.1611788410873115e-06
# dbytes 	 1.3150233671933963e-05 	 -2.317791879856502e-07 	 -5.310117252270749e-05
# sttl 	 -2.118618325900837e-09 	 9.259538696130696e-11 	 2.432836502168553e-07
# dttl 	 1.8757171215440586e-09 	 1.291265946262289e-10 	 -5.425632067858871e-08
# service 	 1.0583081240441339e-10 	 -8.955107009452748e-13 	 -1.3094136566966652e-10
# Sload 	 -0.0032766373053334874 	 8.615701178972812e-05 	 0.9999909236057848
# Dload 	 0.0006803955076612198 	 -1.093787178014228e-05 	 -0.0027191926920468487
# Spkts 	 1.0786255591931968e-08 	 -2.506876299796993e-10 	 -3.58987375787441e-08
# Dpkts 	 1.4608195692077992e-08 	 -3.214953025911146e-10 	 -5.611339418948043e-08
# swin 	 4.944920482480673e-08 	 1.0195876288579097e-10 	 -1.283380382064491e-07
# dwin 	 4.9534767251627815e-08 	 1.7442980476573046e-12 	 -1.373442347410864e-07
# stcpb 	 0.7066332810971886 	 0.7075762147799448 	 0.002255709954338136
# dtcpb 	 0.707572050450855 	 -0.7066370304017076 	 0.0023806744101421643
# smeansz 	 9.832091801153498e-09 	 6.7388086631723e-11 	 3.403636767615848e-07
# dmeansz 	 7.422861109684608e-08 	 -4.4712213144167146e-10 	 -4.026746631746148e-07
# trans_depth 	 2.5969198317926365e-11 	 3.8147284593527993e-13 	 -1.0549678489256842e-10
# res_bdy_len 	 1.2789133850247538e-06 	 -7.00766269391339e-08 	 -5.6664049725201954e-06
# Sjit 	 4.5643264231673497e-07 	 1.1834437412064589e-07 	 -2.0478314829474993e-06
# Djit 	 2.472664544774901e-07 	 3.7337239667251646e-08 	 -1.1587864543192505e-06
# tcprtt 	 9.309768323161196e-13 	 1.0158809494045652e-13 	 -3.862001054839727e-12
# synack 	 5.131536409788735e-13 	 4.900951841393904e-14 	 -2.1283671788738194e-12
# ackdat 	 4.178231913372471e-13 	 5.257857652651738e-14 	 -1.7336338759659058e-12
# ct_state_ttl 	 -2.593615701495169e-11 	 5.691909983557417e-13 	 2.039968581490915e-09
# ct_flw_http_mthd 	 4.624407326447242e-11 	 3.6998031069218734e-12 	 -1.808431411627639e-10
# is_ftp_login 	 5.546912001999448e-12 	 -3.943457680191515e-13 	 -2.1011470924207637e-11
# ct_ftp_cmd 	 8.994860992804069e-12 	 -1.4378656095601992e-12 	 -3.2609207577803196e-11
# ct_srv_src 	 1.8889088248490412e-10 	 1.025674735925831e-13 	 7.142113102917375e-09
# ct_srv_dst 	 1.2338874219529593e-10 	 2.1605152136868937e-12 	 6.738579635285169e-09
# ct_dst_ltm 	 9.114016740757525e-11 	 -2.8186616507756135e-14 	 -2.3712569821707765e-10
# ct_src_ ltm 	 1.2660043278993642e-10 	 1.968142503771351e-12 	 -2.2640844768169398e-10
# ct_src_dport_ltm 	 2.340617356851311e-12 	 2.1054285956510978e-12 	 3.6896249226815234e-09
# ct_dst_sport_ltm 	 1.2465887137751002e-11 	 5.911688066780969e-14 	 2.019533456554579e-09
# ct_dst_src_ltm 	 2.0810339530235124e-11 	 -4.354276629829491e-12 	 3.042846693514939e-09

# %%
attributesorted = sorted(attributeimportance.items(), key=lambda x: x[1], reverse = True)
print(attributesorted)
# Out:
# [('dtcpb', 1.0009266407933521), ('stcpb', 1.0008046995624005), ('Sload', 0.9950058148975898), ('Dload', 0.0031866895483905915), ('dbytes', 6.214703165584852e-05), ('res_bdy_len', 6.57606773527362e-06), ('Sjit', 2.438287037492203e-06), ('sbytes', 2.069948118722063e-06), ('Djit', 1.3510162839776236e-06), ('dmeansz', 4.52369300408227e-07), ('smeansz', 3.4484032151426336e-07), ('sttl', 2.4305329332243546e-07), ('dwin', 1.7126351949911564e-07), ('swin', 1.6233410233194904e-07), ('Dpkts', 6.622858046408818e-08), ('dttl', 5.5271105164285735e-08), ('Spkts', 4.3417605681715974e-08), ('ct_srv_src', 7.2228368832346484e-09), ('ct_srv_dst', 6.777539619209631e-09), ('state', 5.536585513515343e-09), ('ct_src_dport_ltm', 3.6656211208798224e-09), ('ct_dst_src_ltm', 3.0382145606960274e-09), ('ct_state_ttl', 2.0436522590657026e-09), ('ct_dst_sport_ltm', 2.013508527962432e-09), ('dur', 1.8683204939807574e-09), ('proto', 6.710836947800821e-10), ('ct_src_ ltm', 3.1540416745963666e-10), ('ct_dst_ltm', 2.9966683149907223e-10), ('ct_flw_http_mthd', 2.147368010684118e-10), ('service', 2.0523570629725448e-10), ('trans_depth', 1.2330206680448156e-10), ('ct_ftp_cmd', 3.972851378054796e-11), ('is_ftp_login', 2.504701629888343e-11), ('tcprtt', 4.561878077662897e-12), ('synack', 2.5092021484166744e-12), ('ackdat', 2.0526759292462208e-12)]

# %% [markdown]
# 2. Singular Value Decomposition(SVD):

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import TruncatedSVD

svd_n = []
svd_n_f1 = []
for i in range(1,10):
  steps = [('svd', TruncatedSVD(n_components=i)), ('m', LogisticRegression())]
  pipeline_model = Pipeline(steps=steps)
  cv_res = cross_validate(estimator=pipeline_model,X=data,y=target,n_jobs=-1,cv=10,scoring = 'accuracy',return_train_score = True)
  y_pred = cross_val_predict(estimator=pipeline_model,X=data,y=target,n_jobs=-1,cv=10)
  svd_n_f1.append(f1_score(target,y_pred))
  svd_n.append(i)

plt.scatter(x=svd_n, y=svd_n_f1)

best_svd_n = svd_n_f1.index(max(svd_n_f1)) + 1
print('\nBest n value: ',best_svd_n)
plt.scatter(x=best_svd_n, y=svd_n_f1[best_svd_n - 1], color='red')
plt.show()
# Out:
# Best n value:  4

# %%
steps = [('svd', TruncatedSVD(n_components=4)), ('m', KNeighborsClassifier())]
svd_model = Pipeline(steps=steps)
cross_val(svd_model,data)
# Out:
# ----------------- After cross validation -----------------
# Training Score: 0.9810449841785409
# Testing Score: 0.9719255045102732
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97    677786
#            1       0.96      0.99      0.97    677786
#
#     accuracy                           0.97   1355572
#    macro avg       0.97      0.97      0.97   1355572
# weighted avg       0.97      0.97      0.97   1355572

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components=4)
svd.fit(data)
# Out:
# TruncatedSVD(n_components=4)

# %%
# Select the features that have the highest singular values
df_reduced = svd.transform(data)
svd.feature_names_in_
svd.singular_values_
svd.components_
svd.explained_variance_
svd.explained_variance_ratio_
svd.algorithm
svd.n_components
#df_reduced.get_feature_names_out(data.columns)
# features = df_reduced.columns[svd.singular_values_].sort_values(ascending=False)
svd.components_
# # Print the selected features
# print(features)
#df_reduced.columns
# Out:
# array([[ 3.11967331e-08,  1.35797160e-09,  2.42220254e-10,
#          1.90971535e-06,  1.86548250e-05,  9.66373437e-09,
#          9.51733735e-09,  4.72104553e-10,  3.13480177e-04,
#          1.10653045e-03,  1.58803260e-08,  2.11729050e-08,
#          6.97803681e-08,  6.97408742e-08,  7.06670854e-01,
#          7.07541504e-01,  3.94264322e-08,  1.24865133e-07,
#          3.64468198e-11,  1.84251587e-06,  6.69445701e-07,
#          3.62433368e-07,  1.32153420e-12,  7.32827367e-13,
#          5.88706833e-13,  8.34037119e-12,  6.37961502e-11,
#          7.62344919e-12,  1.21779718e-11,  1.82473789e-09,
#          1.70388159e-09,  1.17439358e-09,  1.32983227e-09,
#          4.62204786e-10,  3.88741615e-10,  6.07575616e-10],
#        [ 6.79301933e-11,  3.50630817e-12,  1.89190889e-13,
#          8.60921947e-09, -4.38998090e-08,  8.86952387e-11,
#          1.24068903e-10,  1.72273509e-12,  8.37782192e-05,
#         -7.83790943e-06, -1.33938755e-10, -1.44523885e-10,
#          1.41226447e-10,  4.33096011e-11,  7.07541958e-01,
#         -7.06671332e-01,  1.02056053e-10, -9.61266186e-12,
#          3.45644816e-13, -7.01392286e-08,  1.35105383e-07,
#          4.22122997e-08,  6.75248565e-14,  3.78110939e-14,
#          2.97137626e-14,  5.36527089e-13,  3.59434321e-12,
#         -4.01666558e-13, -1.30082445e-12, -1.84718343e-12,
#          2.74436629e-12,  9.02786824e-13,  1.36894561e-12,
#          3.62446151e-12,  1.81311489e-12, -2.51389437e-12],
#        [ 2.28538520e-07,  1.15084488e-08, -1.93269316e-10,
#          3.29055971e-06, -1.27325880e-05,  3.25356954e-07,
#          1.65840647e-09,  2.50287029e-09,  9.99999870e-01,
#          3.92290399e-04,  1.36094412e-09, -7.97737659e-09,
#          1.93591510e-08,  1.03263730e-08, -2.81108584e-04,
#         -1.62905976e-04,  5.43450830e-07, -3.29016061e-08,
#         -2.86521961e-11, -1.56552813e-06, -5.16068455e-07,
#         -3.17854707e-07, -9.41094621e-13, -4.76695579e-13,
#         -4.64399042e-13,  2.26384483e-09, -5.11623494e-11,
#         -5.30555104e-12, -8.50904244e-12,  1.87406649e-08,
#          1.79489154e-08,  7.56007129e-09,  8.43390619e-09,
#          6.93735608e-09,  4.69520957e-09,  7.21565641e-09],
#        [ 3.73587667e-06,  1.39534627e-07, -8.67317627e-08,
#         -2.76496362e-04,  8.81607384e-04,  4.73063985e-07,
#          2.57405535e-07, -1.35201526e-07, -3.92624848e-04,
#          9.99998830e-01,  1.46248526e-06,  1.02273807e-06,
#          6.25494464e-06,  6.27107067e-06, -7.76307970e-04,
#         -7.88402341e-04, -6.19096044e-06,  3.77242546e-05,
#         -1.36412970e-08, -9.22505926e-05, -2.76432131e-04,
#         -1.45220563e-04, -4.65157367e-10, -2.32414392e-10,
#         -2.32742976e-10, -3.73784755e-09, -2.46288055e-08,
#         -3.07079144e-09, -4.91462847e-09,  3.61598378e-07,
#          2.91376781e-07,  6.43703719e-08,  1.27151712e-07,
#          1.76337171e-09,  1.71653194e-08,  8.99483178e-09]])

# %%
components = svd.components_
print("Component Matrix:")
print(components)
# Out:
# Component Matrix:
# [[ 3.14905112e-08  1.37238264e-09  3.71330716e-10  4.37304746e-06
#    1.43598740e-05  2.46301473e-08  3.14080887e-08  4.80706134e-10
#    2.08408930e-04  7.17355834e-04  1.39597094e-08  1.66255484e-08
#    7.04378283e-08  7.04066710e-08  7.09344241e-01  7.04861823e-01
#    4.53865865e-08  9.91685273e-08  2.53570587e-11  1.31037578e-06
#    2.45642328e-06  3.85501721e-07  1.33450169e-11  6.63166255e-12
#    6.71335435e-12  1.06571970e-10  4.25788728e-11  5.03555170e-12
#    7.96232711e-12  1.46209300e-09  1.32061334e-09  8.82189073e-10
#    1.01288031e-09  4.08693065e-10  3.55557090e-10  5.06006742e-10]
#  [ 2.13317172e-11 -2.13340159e-13  1.07608980e-11 -3.32483652e-07
#    1.92225967e-07 -6.61898024e-10 -1.15149977e-09  2.20333817e-13
#   -4.42441284e-05  2.66167729e-05  1.27719225e-10  3.09912376e-10
#    5.43872060e-11  1.25366658e-10 -7.04862025e-01  7.09344432e-01
#    1.53494853e-10  3.65891265e-10  1.46358716e-12  5.56747446e-08
#   -1.10799781e-06 -4.68935537e-08 -4.15333689e-13 -1.29369796e-13
#   -2.85963892e-13 -4.88737438e-12 -2.05546339e-13  4.57276920e-13
#    1.07520292e-12  8.40467973e-12  1.53210299e-11  1.63853824e-11
#    1.67381378e-11 -9.43594812e-13 -1.80402643e-12  7.16329261e-12]
#  [ 1.97338636e-07  1.04917849e-08  7.32150998e-13  1.24371537e-06
#   -5.55917128e-07  4.32468830e-07 -1.01664567e-09  1.25673085e-09
#    9.99999976e-01  4.35256681e-05  3.60399623e-09 -2.29935888e-10
#    1.14236042e-09  5.95313594e-10 -1.79041087e-04 -1.15538080e-04
#    5.08817251e-07 -7.10866337e-10 -1.16214122e-12 -6.79044555e-08
#   -4.57610257e-08 -2.08698728e-08 -6.77795528e-13 -3.34214740e-13
#   -3.43580788e-13  3.40326897e-09 -2.00019114e-12 -1.88682558e-13
#   -2.99420533e-13  1.65279079e-08  1.54378909e-08  6.23948443e-09
#    7.56794946e-09  5.97284010e-09  4.45956751e-09  6.07639355e-09]
#  [ 3.10121678e-06  1.14515776e-07 -1.21125992e-07 -1.16622362e-03
#    2.63072989e-03 -5.19423154e-06 -7.82884135e-06 -1.17823143e-07
#   -4.36709276e-05  9.99995170e-01  1.98012724e-06  2.76977536e-06
#    5.15189965e-06  5.16219835e-06 -4.90101511e-04 -5.24532818e-04
#   -7.57054167e-06  4.24241561e-05 -7.53286917e-09  1.33823926e-04
#   -9.08047531e-04 -1.32555699e-04 -4.84555177e-09 -2.38482768e-09
#   -2.46072409e-09 -3.95055134e-08 -1.31932739e-08 -1.67258543e-09
#   -2.64929155e-09  4.42499526e-07  3.90114575e-07  1.63031555e-07
#    2.25810629e-07  2.12198885e-08  2.69310095e-08  4.51591324e-08]]

# %%
svdattributes = {}
svdattributeimportance = {}
svdsum = [sum(abs(components[0])),sum(abs(components[1])),sum(abs(components[2])),sum(abs(components[3]))]
for i in range(len(data.columns)):
    svdattributes[data.columns[i]] = [components[0][i],components[1][i],components[2][i],components[3][i]]
    svdattributeimportance[data.columns[i]] = abs(components[0][i])/svdsum[0]+abs(components[1][i])/svdsum[1]+abs(components[2][i])/svdsum[2]+abs(components[3][i])/svdsum[3]
    print(data.columns[i],'\t',components[0][i],'\t',components[1][i],'\t',components[2][i],'\t',components[3][i])
# Out:
# proto 	 3.149051119865237e-08 	 2.1331717175997786e-11 	 1.9733863613506408e-07 	 3.1012167819863384e-06
# state 	 1.3723826360909166e-09 	 -2.1334015894721814e-13 	 1.0491784903900908e-08 	 1.1451577610589859e-07
# dur 	 3.713307156331017e-10 	 1.0760897968080979e-11 	 7.321509983450606e-13 	 -1.211259915574014e-07
# sbytes 	 4.373047455590057e-06 	 -3.3248365165719447e-07 	 1.2437153669246475e-06 	 -0.0011662236237775948
# dbytes 	 1.4359873969603333e-05 	 1.9222596725609737e-07 	 -5.559171277911461e-07 	 0.002630729886294053
# sttl 	 2.463014730264645e-08 	 -6.618980240932217e-10 	 4.3246883037970957e-07 	 -5.194231535395179e-06
# dttl 	 3.1408088732909704e-08 	 -1.1514997656317866e-09 	 -1.0166456749074187e-09 	 -7.828841348143802e-06
# service 	 4.807061337934014e-10 	 2.203338172632584e-13 	 1.2567308454625522e-09 	 -1.1782314295714581e-07
# Sload 	 0.0002084089302839614 	 -4.4244128414048775e-05 	 0.9999999763492041 	 -4.367092761124237e-05
# Dload 	 0.0007173558337597494 	 2.661677293685613e-05 	 4.3525668149333096e-05 	 0.9999951699338182
# Spkts 	 1.3959709442668562e-08 	 1.2771922485068308e-10 	 3.603996233881392e-09 	 1.9801272397247745e-06
# Dpkts 	 1.6625548362062838e-08 	 3.0991237643366277e-10 	 -2.2993588804235008e-10 	 2.769775356327578e-06
# swin 	 7.043782829413216e-08 	 5.43872059635871e-11 	 1.1423604242062244e-09 	 5.151899651200906e-06
# dwin 	 7.040667096898871e-08 	 1.2536665755137852e-10 	 5.953135942072682e-10 	 5.162198346756729e-06
# stcpb 	 0.7093442414597733 	 -0.7048620253290604 	 -0.00017904108711074463 	 -0.0004901015110631776
# dtcpb 	 0.7048618225162504 	 0.7093444315575047 	 -0.00011553808038015296 	 -0.0005245328178599929
# smeansz 	 4.538658646704399e-08 	 1.534948532921044e-10 	 5.088172513127951e-07 	 -7.570541673480691e-06
# dmeansz 	 9.916852726081593e-08 	 3.6589126469222224e-10 	 -7.108663370468564e-10 	 4.2424156134807576e-05
# trans_depth 	 2.535705871917129e-11 	 1.4635871647165821e-12 	 -1.1621412222928623e-12 	 -7.532869171780224e-09
# res_bdy_len 	 1.3103757804715619e-06 	 5.5674744648760076e-08 	 -6.790445551590749e-08 	 0.00013382392618381813
# Sjit 	 2.456423276605783e-06 	 -1.1079978120661335e-06 	 -4.576102573856385e-08 	 -0.0009080475311512193
# Djit 	 3.855017205418077e-07 	 -4.689355370713457e-08 	 -2.0869872848053255e-08 	 -0.00013255569896083723
# tcprtt 	 1.33450168963629e-11 	 -4.153336886449205e-13 	 -6.77795527810196e-13 	 -4.845551770289454e-09
# synack 	 6.631662550910163e-12 	 -1.29369796300591e-13 	 -3.3421474027112897e-13 	 -2.3848276805793535e-09
# ackdat 	 6.71335434545271e-12 	 -2.859638923443303e-13 	 -3.435807875390678e-13 	 -2.4607240897101112e-09
# ct_state_ttl 	 1.0657197008835824e-10 	 -4.8873743781008934e-12 	 3.4032689743425627e-09 	 -3.950551343690266e-08
# ct_flw_http_mthd 	 4.2578872811464276e-11 	 -2.0554633948199242e-13 	 -2.0001911352880343e-12 	 -1.3193273861782054e-08
# is_ftp_login 	 5.03555169649372e-12 	 4.572769198756449e-13 	 -1.886825583062457e-13 	 -1.6725854296121952e-09
# ct_ftp_cmd 	 7.96232710859935e-12 	 1.0752029206644778e-12 	 -2.994205328064555e-13 	 -2.649291545440073e-09
# ct_srv_src 	 1.462092996423572e-09 	 8.4046797263794e-12 	 1.6527907899161404e-08 	 4.424995259298885e-07
# ct_srv_dst 	 1.3206133418655366e-09 	 1.532102987080944e-11 	 1.5437890858319913e-08 	 3.9011457466625543e-07
# ct_dst_ltm 	 8.82189072862167e-10 	 1.6385382355579578e-11 	 6.23948442942062e-09 	 1.63031555282761e-07
# ct_src_ ltm 	 1.0128803136831876e-09 	 1.673813784000344e-11 	 7.567949458206591e-09 	 2.2581062888156866e-07
# ct_src_dport_ltm 	 4.086930647816071e-10 	 -9.435948117175249e-13 	 5.972840104332522e-09 	 2.1219888521402292e-08
# ct_dst_sport_ltm 	 3.555570904599814e-10 	 -1.8040264288361156e-12 	 4.4595675110990575e-09 	 2.693100949585352e-08
# ct_dst_src_ltm 	 5.060067420290104e-10 	 7.163292611646752e-12 	 6.076393548961427e-09 	 4.515913240368167e-08

# %%
print("Attribute Importance:")
print(svdattributeimportance)
# Out:
# Attribute Importance:
# {'proto': 3.301928957942674e-06, 'state': 1.2527871703857134e-07, 'dur': 1.206614080823226e-07, 'sbytes': 0.0011637123625589851, 'dbytes': 0.002625598360893934, 'sttl': 5.6128927724829e-06, 'dttl': 7.805339369557256e-06, 'service': 1.1870401602253532e-07, 'Sload': 0.9998808130521782, 'Dload': 0.994493736991078, 'Spkts': 1.9816639871397837e-06, 'Dpkts': 2.765158077966253e-06, 'swin': 5.171578353365423e-06, 'dwin': 5.181295839211168e-06, 'stcpb': 1.0003041424154224, 'dtcpb': 1.0002768364236128, 'smeansz': 8.065407189706901e-06, 'dmeansz': 4.223765711005741e-05, 'trans_depth': 7.50725418958775e-09, 'res_bdy_len': 0.00013404472746893968, 'Sjit': 0.0009051000242522446, 'Djit': 0.0001320774221908701, 'tcprtt': 4.826537175128039e-09, 'synack': 2.375461848840062e-09, 'ackdat': 2.4510753262879884e-09, 'ct_state_ttl': 4.2746558608908617e-08, 'ct_flw_http_mthd': 1.3145414040253908e-08, 'is_ftp_login': 1.666501911083703e-09, 'ct_ftp_cmd': 2.6398945197795902e-09, 'ct_srv_src': 4.573746234164119e-07, 'ct_srv_dst': 4.0412295612134395e-07, 'ct_dst_ltm': 1.6891416767837442e-07, 'ct_src_ ltm': 2.3273274064006657e-07, 'ct_src_dport_ltm': 2.735133607184626e-08, 'ct_dst_sport_ltm': 3.147809072593566e-08, 'ct_dst_src_ltm': 5.132193320449328e-08}
