# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from sklearn.neighbors import LocalOutlierFactor

from sklearn.preprocessing import StandardScaler


# Load your dataset
df = pd.read_csv(r'C:\Users\jagad\Documents\GitHub\Graph-Anomaly-Detection\datasets\combined_data.csv')

# Drop specified columns
columns_to_drop = ['dsport', 'sloss', 'dloss', 'Sintpkt', 'Dintpkt', 'Stime', 'Ltime', 'attack_cat']
df = df.drop(columns=columns_to_drop)

# Convert column names to lowercase
df.columns = df.columns.str.lower()

sample_df = df.head(6000)

# Create a directed graph
G = nx.DiGraph()
count = 0
countatt = 0
# Iterate through the sample and add nodes and edges to the graph
for index, row in sample_df.iterrows():
    src_ip = row['srcip']
    dst_ip = row['dstip']
    if src_ip == dst_ip:
        continue
    # Add nodes
    G.add_node(src_ip)
    G.add_node(dst_ip)
    if row['label'] == 1:
        countatt = 1
        edge_attributes = row.drop(['srcip', 'dstip']).to_dict()
        G.add_edge(src_ip, dst_ip, **edge_attributes)
    else:
        if count < 9:
    # Add directed edge with specified attributes
            edge_attributes = row.drop(['srcip', 'dstip']).to_dict()
            G.add_edge(src_ip, dst_ip, **edge_attributes)
            count += 1
    if count >= 10:
        break
        
    

# Draw the graph
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=2000, font_size=10, font_color='black', node_color='lightblue', font_weight='bold', arrowsize=20)
plt.show()
# Out:
# C:\Users\jagad\AppData\Local\Temp\ipykernel_4468\3420688322.py:12: DtypeWarning: Columns (1,3,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\jagad\Documents\GitHub\Graph-Anomaly-Detection\datasets\UNSW-NB15_1.csv', names=headers)

# %%
import os

# Specify the path for the output GEXF file in the Downloads folder
output_file_path = os.path.join(os.path.expanduser('~'), r'C:\Users\jagad\Downloads', 'graph_output.gexf')


# Write the graph to a GEXF file
nx.write_gexf(G, output_file_path)

print(f"Graph has been written to {output_file_path}")
# Out:
# Graph has been written to C:\Users\jagad\Downloads\graph_output.gexf

# %%
from neo4j import GraphDatabase

# URI examples: "neo4j://localhost", "neo4j+s://xxx.databases.neo4j.io"
URI = "bolt://localhost:7687"
AUTH = ("neo4j", "password")

with GraphDatabase.driver(URI, auth=AUTH) as driver: 
    driver.verify_connectivity()

# %%
import csv
from neo4j import GraphDatabase

# Assuming you have a Neo4j server running locally
uri = "bolt://localhost:7687"
username = "neo4j"
password = "password"

def create_node(tx, ip_address):
    query = (
        "MERGE (n:IP {ip_address: $ip_address})"
    )
    tx.run(query, ip_address=ip_address)

# Read nodes from CSV file
nodes = []
with open(r'C:\Users\jagad\Documents\GitHub\Graph-Anomaly-Detection\datasets\combined_data.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        # Assuming 'srcip' is the column containing IP addresses
        nodes.append({'ip_address': row['srcip']})

# List of edges (replace with your actual data)
edges = [
    {'src_ip': '192.168.1.1', 'dst_ip': '192.168.1.2', 'label': 'some_label', 'proto': 'TCP', 'state': 'ESTABLISHED', 'dur': 10, 'spkts': 100, 'dpkts': 50}
]

# Create a Neo4j session
with GraphDatabase.driver(uri, auth=(username, password)) as driver:
    with driver.session() as session:
        # Create nodes
        for node in nodes:
            session.write_transaction(create_node, node['ip_address'])

        # Create relationships
        with driver.session() as session:
            for edge in edges:
                session.run("""
                    MATCH (src:IP {ip_address: $src_ip}), (dst:IP {ip_address: $dst_ip})
                    MERGE (src)-[:COMMUNICATES_WITH {label: $label, proto: $proto, state: $state, dur: $dur, spkts: $spkts, dpkts: $dpkts}]->(dst)
                """, src_ip=edge['src_ip'], dst_ip=edge['dst_ip'], label=edge['label'], proto=edge['proto'], state=edge['state'], dur=edge['dur'],
                spkts=edge['spkts'], dpkts=edge['dpkts'])
# Out:
# C:\Users\jagad\AppData\Local\Temp\ipykernel_4496\2010795508.py:33: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(create_node, node['ip_address'])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\jagad\Documents\GitHub\Graph-Anomaly-Detection\graph_neo4j_nodecreation.ipynb Cell 4 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/graph_neo4j_nodecreation.ipynb#W3sZmlsZQ%3D%3D?line=29'>30</a> with driver.session() as session:
#      <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/graph_neo4j_nodecreation.ipynb#W3sZmlsZQ%3D%3D?line=30'>31</a>     # Create nodes
#      <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/graph_neo4j_nodecreation.ipynb#W3sZmlsZQ%3D%3D?line=31'>32</a>     for node in nodes:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/graph_neo4j_nodecreation.ipynb#W3sZmlsZQ%3D%3D?line=32'>33</a>         session.write_transaction(create_node, node['ip_address'])
#      <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/graph_neo4j_nodecreation.ipynb#W3sZmlsZQ%3D%3D?line=34'>35</a>     # Create relationships
#      <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/graph_neo4j_nodecreation.ipynb#W3sZmlsZQ%3D%3D?line=35'>36</a>     with driver.session() as session:
#
# File c:\Users\jagad\anaconda3\envs\tensorflow_env\lib\site-packages\neo4j\_meta.py:219, in _make_warning_decorator.<locals>.decorator.<locals>.inner(*args, **kwargs)
#     216 @wraps(f)
#     217 def inner(*args, **kwargs):
#     218     warning_func(message, stack_level=2)
# --> 219     return f(*args, **kwargs)
#
# File c:\Users\jagad\anaconda3\envs\tensorflow_env\lib\site-packages\neo4j\_sync\work\session.py:796, in Session.write_transaction(self, transaction_function, *args, **kwargs)
#     762 @deprecated("write_transaction has been renamed to execute_write")
#     763 @NonConcurrentMethodChecker.non_concurrent_method
#     764 def write_transaction(
#    (...)
#     769     *args: _P.args,  **kwargs: _P.kwargs
#     770 ) -> _R:
#     771     """Execute a unit of work in a managed write transaction.
#     772
#     773     .. note::
#    (...)
#     794         Method was renamed to :meth:`.execute_write`.
#     795     """
# --> 796     return self._run_transaction(
#     797         WRITE_ACCESS, TelemetryAPI.TX_FUNC,
#     798         transaction_function, args, kwargs
#     799     )
#
# File c:\Users\jagad\anaconda3\envs\tensorflow_env\lib\site-packages\neo4j\_sync\work\session.py:551, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     549 tx = self._transaction
#     550 try:
# --> 551     result = transaction_function(tx, *args, **kwargs)
#     552 except asyncio.CancelledError:
#     553     # if cancellation callback has not been called yet:
#     554     if self._transaction is not None:
#
# c:\Users\jagad\Documents\GitHub\Graph-Anomaly-Detection\graph_neo4j_nodecreation.ipynb Cell 4 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/graph_neo4j_nodecreation.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a> def create_node(tx, ip_address):
#      <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/graph_neo4j_nodecreation.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a>     query = (
#      <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/graph_neo4j_nodecreation.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a>         "MERGE (n:IP {ip_address: $ip_address})"
#      <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/graph_neo4j_nodecreation.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a>     )
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/graph_neo4j_nodecreation.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a>     tx.run(query, ip_address=ip_address)
#
# File c:\Users\jagad\anaconda3\envs\tensorflow_env\lib\site-packages\neo4j\_sync\work\transaction.py:169, in TransactionBase.run(self, query, parameters, **kwparameters)
#     166 self._results.append(result)
#     168 parameters = dict(parameters or {}, **kwparameters)
# --> 169 result._tx_ready_run(query, parameters)
#     171 return result
#
# File c:\Users\jagad\anaconda3\envs\tensorflow_env\lib\site-packages\neo4j\_sync\work\result.py:131, in Result._tx_ready_run(self, query, parameters)
#     127 def _tx_ready_run(self, query, parameters):
#     128     # BEGIN+RUN does not carry any extra on the RUN message.
#     129     # BEGIN {extra}
#     130     # RUN "query" {parameters} {extra}
# --> 131     self._run(query, parameters, None, None, None, None, None, None)
#
# File c:\Users\jagad\anaconda3\envs\tensorflow_env\lib\site-packages\neo4j\_sync\work\result.py:180, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_categories)
#     163 self._connection.run(
#     164     query_text,
#     165     parameters=parameters,
#    (...)
#     177     on_failure=on_failed_attach,
#     178 )
#     179 self._pull()
# --> 180 self._connection.send_all()
#     181 self._attach()
#
# File c:\Users\jagad\anaconda3\envs\tensorflow_env\lib\site-packages\neo4j\_sync\io\_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     176 def inner(*args, **kwargs):
#     177     try:
# --> 178         func(*args, **kwargs)
#     179     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     180         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File c:\Users\jagad\anaconda3\envs\tensorflow_env\lib\site-packages\neo4j\_sync\io\_bolt.py:818, in Bolt.send_all(self)
#     811 if self.defunct():
#     812     raise ServiceUnavailable(
#     813         "Failed to write to defunct connection {!r} ({!r})".format(
#     814             self.unresolved_address, self.server_info.address
#     815         )
#     816     )
# --> 818 self._send_all()
#
# File c:\Users\jagad\anaconda3\envs\tensorflow_env\lib\site-packages\neo4j\_sync\io\_bolt.py:799, in Bolt._send_all(self)
#     798 def _send_all(self):
# --> 799     if self.outbox.flush():
#     800         self.idle_since = perf_counter()
#
# File c:\Users\jagad\anaconda3\envs\tensorflow_env\lib\site-packages\neo4j\_sync\io\_common.py:139, in Outbox.flush(self)
#     137 if data:
#     138     try:
# --> 139         self.socket.sendall(data)
#     140     except (
#     141         OSError, SocketDeadlineExceeded, asyncio.CancelledError
#     142     ) as error:
#     143         Util.callback(self.on_error, error)
#
# File c:\Users\jagad\anaconda3\envs\tensorflow_env\lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:496, in BoltSocket.sendall(self, data)
#     495 def sendall(self, data):
# --> 496     return self._wait_for_io(self._socket.sendall, data)
#
# File c:\Users\jagad\anaconda3\envs\tensorflow_env\lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:468, in BoltSocket._wait_for_io(self, func, *args, **kwargs)
#     466 def _wait_for_io(self, func, *args, **kwargs):
#     467     if self._deadline is None:
# --> 468         return func(*args, **kwargs)
#     469     timeout = self._socket.gettimeout()
#     470     deadline_timeout = self._deadline.to_timeout()
#
# KeyboardInterrupt:

# %%
from neo4j import GraphDatabase
import csv

# Assuming you have a Neo4j server running locally
uri = "bolt://localhost:7687"
username = "neo4j"
password = "password"

def create_edge(tx, edge):
    query = (
        """
        MATCH (src:IP {ip_address: $src_ip}), (dst:IP {ip_address: $dst_ip})
        MERGE (src)-[:COMMUNICATES_WITH {label: $label, proto: $proto, state: $state, dur: $dur, spkts: $spkts, dpkts: $dpkts}]->(dst)
        """
    )
    tx.run(query, src_ip=edge['src_ip'], dst_ip=edge['dst_ip'], label=edge['some_label'], proto=edge['proto'], state=edge['state'], dur=edge['dur'], spkts=edge['spkts'], dpkts=edge['dpkts'])


# Read nodes from CSV file
nodes = []
with open(r'C:\Users\jagad\Documents\GitHub\Graph-Anomaly-Detection\datasets\combined_data.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        # Assuming 'srcip' and 'dstip' are the columns containing IP addresses
        nodes.append({'src_ip': row['srcip'], 'dst_ip': row['dstip']})

# Create a Neo4j session
with GraphDatabase.driver(uri, auth=(username, password)) as driver:
    with driver.session() as session:
        # Create relationships
        for edge in nodes:
            session.write_transaction(create_edge, edge)
# Out:
# C:\Users\jagad\AppData\Local\Temp\ipykernel_10064\4104445661.py:32: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(create_edge, edge)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\jagad\Documents\GitHub\Graph-Anomaly-Detection\Untitled-1.ipynb Cell 5 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/Untitled-1.ipynb#X25sZmlsZQ%3D%3D?line=28'>29</a> with driver.session() as session:
#      <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/Untitled-1.ipynb#X25sZmlsZQ%3D%3D?line=29'>30</a>     # Create relationships
#      <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/Untitled-1.ipynb#X25sZmlsZQ%3D%3D?line=30'>31</a>     for edge in nodes:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/Untitled-1.ipynb#X25sZmlsZQ%3D%3D?line=31'>32</a>         session.write_transaction(create_edge, edge)
#
# File c:\Users\jagad\anaconda3\lib\site-packages\neo4j\_meta.py:219, in _make_warning_decorator.<locals>.decorator.<locals>.inner(*args, **kwargs)
#     216 @wraps(f)
#     217 def inner(*args, **kwargs):
#     218     warning_func(message, stack_level=2)
# --> 219     return f(*args, **kwargs)
#
# File c:\Users\jagad\anaconda3\lib\site-packages\neo4j\_sync\work\session.py:796, in Session.write_transaction(self, transaction_function, *args, **kwargs)
#     762 @deprecated("write_transaction has been renamed to execute_write")
#     763 @NonConcurrentMethodChecker.non_concurrent_method
#     764 def write_transaction(
#    (...)
#     769     *args: _P.args,  **kwargs: _P.kwargs
#     770 ) -> _R:
#     771     """Execute a unit of work in a managed write transaction.
#     772
#     773     .. note::
#    (...)
#     794         Method was renamed to :meth:`.execute_write`.
#     795     """
# --> 796     return self._run_transaction(
#     797         WRITE_ACCESS, TelemetryAPI.TX_FUNC,
#     798         transaction_function, args, kwargs
#     799     )
#
# File c:\Users\jagad\anaconda3\lib\site-packages\neo4j\_sync\work\session.py:551, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     549 tx = self._transaction
#     550 try:
# --> 551     result = transaction_function(tx, *args, **kwargs)
#     552 except asyncio.CancelledError:
#     553     # if cancellation callback has not been called yet:
#     554     if self._transaction is not None:
#
# c:\Users\jagad\Documents\GitHub\Graph-Anomaly-Detection\Untitled-1.ipynb Cell 5 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/Untitled-1.ipynb#X25sZmlsZQ%3D%3D?line=8'>9</a> def create_edge(tx, edge):
#      <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/Untitled-1.ipynb#X25sZmlsZQ%3D%3D?line=9'>10</a>     query = (
#      <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/Untitled-1.ipynb#X25sZmlsZQ%3D%3D?line=10'>11</a>         """
#      <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/Untitled-1.ipynb#X25sZmlsZQ%3D%3D?line=11'>12</a>         MATCH (src:IP {ip_address: $src_ip}), (dst:IP {ip_address: $dst_ip})
#      <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/Untitled-1.ipynb#X25sZmlsZQ%3D%3D?line=12'>13</a>         MERGE (src)-[:COMMUNICATES_WITH {label: $label, proto: $proto, state: $state, dur: $dur, spkts: $spkts, dpkts: $dpkts}]->(dst)
#      <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/Untitled-1.ipynb#X25sZmlsZQ%3D%3D?line=13'>14</a>         """
#      <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/Untitled-1.ipynb#X25sZmlsZQ%3D%3D?line=14'>15</a>     )
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jagad/Documents/GitHub/Graph-Anomaly-Detection/Untitled-1.ipynb#X25sZmlsZQ%3D%3D?line=15'>16</a>     tx.run(query, src_ip=edge['src_ip'], dst_ip=edge['dst_ip'], label=edge['some_label'], proto=edge['proto'], state=edge['state'], dur=edge['dur'], spkts=edge['spkts'], dpkts=edge['dpkts'])
#
# KeyError: 'some_label'

# %%
df.columns
# Out:
# Index(['srcip', 'sport', 'dstip', 'dsport', 'proto', 'state', 'dur', 'sbytes',
#        'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'Sload', 'Dload',
#        'Spkts', 'Dpkts', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz',
#        'dmeansz', 'trans_depth', 'res_bdy_len', 'Sjit', 'Djit', 'Stime',
#        'Ltime', 'Sintpkt', 'Dintpkt', 'tcprtt', 'synack', 'ackdat',
#        'is_sm_ips_ports', 'ct_state_ttl', 'ct_flw_http_mthd', 'is_ftp_login',
#        'ct_ftp_cmd', 'ct_srv_src', 'ct_srv_dst', 'ct_dst_ltm', 'ct_src_ ltm',
#        'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat',
#        'Label'],
#       dtype='object')
